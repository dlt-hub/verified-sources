# %% [markdown]
# # Usage examples for gitpythonfs - an fsspec implementation.
#
# Includes comparison of behaviour with other fsspec implementations, `git` and `file`.

# %% [markdown]
# To get persistent repo_fixture folder as used in these examples:
# - debug run a test that uses `tests.test_core.repo_fixture`, pausing before `shutil.rmtree(d)` deletes the temp dir.
# - get the temp directory location `d`
# - in your os, rename the directoy.  eg  `mv /tmp/tmptdfvh5pe /tmp/repo_fixture`
# - finish or cancel debug run
#
# ToDo: add a persist option to `tests.test_core.repo_fixture`

# %%
import fsspec

# %% [markdown]
# # gitpythonfs

# %%
import gitpythonfs

# %%
path = "/tmp/repo_fixture"
# path = "~/dlt"
fs_gitpythonfs = fsspec.filesystem("gitpythonfs", path=path)

# %%
fs_gitpythonfs.ls("")
# Out:
# ['.dockerignore',
#  '.editorconfig',
#  '.github',
#  '.gitignore',
#  'CONTRIBUTING.md',
#  'LICENSE.txt',
#  'Makefile',
#  'README.md',
#  'check-package.sh',
#  'compiled_packages.txt',
#  'deploy',
#  'dlt',
#  'docs',
#  'mypy.ini',
#  'poetry-deps.sh',
#  'poetry.lock',
#  'pyproject.toml',
#  'pytest.ini',
#  'tests',
#  'tox.ini']

# %% [markdown]
# Note that we got the folder `inner`, because our implementation uses head, which is currently at branch `abranch`.  Different to the `git` fsspec implementation, which defaults to `master` branch.

# %%
fs_gitpythonfs.ls("", detail=True)
# Out:
# [{'name': '.dockerignore',
#   'type': 'file',
#   'mime_type': 'text/plain',
#   'size': 168,
#   'hexsha': '0c3244a411fe1751d82029c92dd8ea68f1cc4b46',
#   'committed_date': 1685729443},
#  {'name': '.editorconfig',
#   'type': 'file',
#   'mime_type': 'text/plain',
#   'size': 319,
#   'hexsha': '82a6b37b3c9f057da069ee0f3bdb7415fe9715e9',
#   'committed_date': 1670792044},
#  {'name': '.github',
#   'type': 'directory',
#   'mime_type': None,
#   'size': 177,
#   'hexsha': '3967419f325f89ea9990877681da2c2a1547b785',
#   'committed_date': 1699459203},
#  {'name': '.gitignore',
#   'type': 'file',
#   'mime_type': 'text/plain',
#   'size': 1869,
#   'hexsha': 'f26ea23d9157be88d5ba5d0822b5df94c3b3362f',
#   'committed_date': 1699374841},
#  {'name': 'CONTRIBUTING.md',
#   'type': 'file',
#   'mime_type': 'text/markdown',
#   'size': 5370,
#   'hexsha': 'c5fb6f9658a0abb1e26f551e9a5b70e142cbdc15',
#   'committed_date': 1692369585},
#  {'name': 'LICENSE.txt',
#   'type': 'file',
#   'mime_type': 'text/plain',
#   'size': 11343,
#   'hexsha': 'fa1b4ed2de7e8dfc9f58fff2bb179d51f00ef21e',
#   'committed_date': 1654274892},
#  {'name': 'Makefile',
#   'type': 'file',
#   'mime_type': 'text/plain',
#   'size': 3310,
#   'hexsha': '85f67818ac83c3e44b2bc33787c3f83a877c717e',
#   'committed_date': 1700246943},
#  {'name': 'README.md',
#   'type': 'file',
#   'mime_type': 'text/markdown',
#   'size': 4528,
#   'hexsha': 'ec56d97ab7daf98ef6c83f1f9041e09d3bc474a5',
#   'committed_date': 1698222755},
#  {'name': 'check-package.sh',
#   'type': 'file',
#   'mime_type': 'text/x-sh',
#   'size': 680,
#   'hexsha': '17767b3eb929f0aea2143cdde66286a0a24f58fe',
#   'committed_date': 1694424101},
#  {'name': 'compiled_packages.txt',
#   'type': 'file',
#   'mime_type': 'text/plain',
#   'size': 56,
#   'hexsha': '5738dbcb079570b439674bfef0647b2dac61c15d',
#   'committed_date': 1654274892},
#  {'name': 'deploy',
#   'type': 'directory',
#   'mime_type': None,
#   'size': 30,
#   'hexsha': '2c9875d8b6e8db02965ac341d26aa786b8526fb0',
#   'committed_date': 1686815984},
#  {'name': 'dlt',
#   'type': 'directory',
#   'mime_type': None,
#   'size': 456,
#   'hexsha': 'bb7fee69f04e3bc1717a187e666717694d9ef7ca',
#   'committed_date': 1700328024},
#  {'name': 'docs',
#   'type': 'directory',
#   'mime_type': None,
#   'size': 144,
#   'hexsha': '5f79bd406945d0574c42f7dcc8274c8dc4939001',
#   'committed_date': 1702388472},
#  {'name': 'mypy.ini',
#   'type': 'file',
#   'mime_type': 'text/plain',
#   'size': 1935,
#   'hexsha': '0d7ab84da9d04153455438badc7c82dbcefbd88b',
#   'committed_date': 1698141179},
#  {'name': 'poetry-deps.sh',
#   'type': 'file',
#   'mime_type': 'text/x-sh',
#   'size': 6880,
#   'hexsha': '4fad8b06c1acee46018b771e7f68ec662307e89c',
#   'committed_date': 1655132990},
#  {'name': 'poetry.lock',
#   'type': 'file',
#   'mime_type': 'text/plain',
#   'size': 625752,
#   'hexsha': 'e925740fb7b94bf759fb67a1c5ad7b0ed520607a',
#   'committed_date': 1699461352},
#  {'name': 'pyproject.toml',
#   'type': 'file',
#   'mime_type': 'text/plain',
#   'size': 5580,
#   'hexsha': 'ba39912867055d501b4bc2d55ba6deb375b25c91',
#   'committed_date': 1700329173},
#  {'name': 'pytest.ini',
#   'type': 'file',
#   'mime_type': 'text/plain',
#   'size': 263,
#   'hexsha': 'fc7ce9119bf003cdc3fc5db0b499777eafbeead8',
#   'committed_date': 1695034480},
#  {'name': 'tests',
#   'type': 'directory',
#   'mime_type': None,
#   'size': 596,
#   'hexsha': '77de56ac75b9f519b92966744aadc1d7b769dd44',
#   'committed_date': 1701446202},
#  {'name': 'tox.ini',
#   'type': 'file',
#   'mime_type': 'text/plain',
#   'size': 355,
#   'hexsha': '7d16160004a265f9e29bea61eb7e77fad1fc90a3',
#   'committed_date': 1680785052}]

# %% [markdown]
# walk() - and therefore find() -  are very slow.  That's because walk() invokes list(detail=True), which then expensively gets committed_date by default. Walk uses detail=True because it needs to discern file vs directory.  You can pass include_committed_date=False to either walk() or find() to speed them up.

# %%
for thing in fs_gitpythonfs.walk(""): # , include_committed_date=False):
    print(thing)
# Out:
# ('', ['.github', 'deploy', 'dlt', 'docs', 'tests'], ['.dockerignore', '.editorconfig', '.gitignore', 'CONTRIBUTING.md', 'LICENSE.txt', 'Makefile', 'README.md', 'check-package.sh', 'compiled_packages.txt', 'mypy.ini', 'poetry-deps.sh', 'poetry.lock', 'pyproject.toml', 'pytest.ini', 'tox.ini'])
# ('.github', ['ISSUE_TEMPLATE', 'workflows'], ['PULL_REQUEST_TEMPLATE.md', 'weaviate-compose.yml'])
# ('.github/ISSUE_TEMPLATE', [], ['bug_report.yml', 'config.yml', 'feature_request.yml'])
# ('.github/workflows', [], ['get_docs_changes.yml', 'lint.yml', 'test_airflow.yml', 'test_build_images.yml', 'test_common.yml', 'test_dbt_cloud.yml', 'test_dbt_runner.yml', 'test_destination_athena.yml', 'test_destination_athena_iceberg.yml', 'test_destination_bigquery.yml', 'test_destination_mssql.yml', 'test_destination_qdrant.yml', 'test_destination_snowflake.yml', 'test_destination_synapse.yml', 'test_destination_weaviate.yml', 'test_destinations.yml', 'test_doc_snippets.yml', 'test_local_destinations.yml'])
# ('deploy', ['dlt'], [])
# ('deploy/dlt', [], ['Dockerfile', 'Dockerfile.airflow', 'README.md'])
# ('dlt', ['cli', 'common', 'destinations', 'extract', 'helpers', 'load', 'normalize', 'pipeline', 'reflection', 'sources'], ['__init__.py', 'py.typed', 'version.py'])
# ('dlt/cli', [], ['__init__.py', '_dlt.py', 'config_toml_writer.py', 'deploy_command.py', 'deploy_command_helpers.py', 'echo.py', 'exceptions.py', 'init_command.py', 'pipeline_command.py', 'pipeline_files.py', 'requirements.py', 'source_detection.py', 'telemetry_command.py', 'utils.py'])
# ('dlt/common', ['configuration', 'data_types', 'data_writers', 'destination', 'json', 'libs', 'normalizers', 'reflection', 'runners', 'runtime', 'schema', 'storages'], ['__init__.py', 'arithmetics.py', 'exceptions.py', 'git.py', 'jsonpath.py', 'pendulum.py', 'pipeline.py', 'source.py', 'time.py', 'typing.py', 'utils.py', 'validation.py', 'wei.py'])
# ('dlt/common/configuration', ['providers', 'specs'], ['__init__.py', 'accessors.py', 'container.py', 'exceptions.py', 'inject.py', 'paths.py', 'resolve.py', 'utils.py'])
# ('dlt/common/configuration/providers', [], ['__init__.py', 'airflow.py', 'context.py', 'dictionary.py', 'environ.py', 'google_secrets.py', 'provider.py', 'toml.py'])
# ('dlt/common/configuration/specs', [], ['__init__.py', 'api_credentials.py', 'aws_credentials.py', 'azure_credentials.py', 'base_configuration.py', 'config_providers_context.py', 'config_section_context.py', 'connection_string_credentials.py', 'exceptions.py', 'gcp_credentials.py', 'known_sections.py', 'run_configuration.py'])
# ('dlt/common/data_types', [], ['__init__.py', 'type_helpers.py', 'typing.py'])
# ('dlt/common/data_writers', [], ['__init__.py', 'buffered.py', 'escape.py', 'exceptions.py', 'writers.py'])
# ('dlt/common/destination', [], ['__init__.py', 'capabilities.py', 'reference.py'])
# ('dlt/common/json', [], ['__init__.py', '_orjson.py', '_simplejson.py'])
# ('dlt/common/libs', [], ['__init__.py', 'pandas.py', 'pyarrow.py', 'pydantic.py'])
# ('dlt/common/normalizers', ['json', 'naming'], ['__init__.py', 'configuration.py', 'exceptions.py', 'typing.py', 'utils.py'])
# ('dlt/common/normalizers/json', [], ['__init__.py', 'relational.py'])
# ('dlt/common/normalizers/naming', [], ['__init__.py', 'direct.py', 'duck_case.py', 'exceptions.py', 'naming.py', 'snake_case.py'])
# ('dlt/common/reflection', [], ['__init__.py', 'function_visitor.py', 'spec.py', 'utils.py'])
# ('dlt/common/runners', [], ['__init__.py', 'configuration.py', 'pool_runner.py', 'runnable.py', 'stdout.py', 'synth_pickle.py', 'typing.py', 'venv.py'])
# ('dlt/common/runtime', [], ['__init__.py', 'collector.py', 'exec_info.py', 'init.py', 'json_logging.py', 'logger.py', 'prometheus.py', 'segment.py', 'sentry.py', 'signals.py', 'slack.py', 'telemetry.py'])
# ('dlt/common/schema', [], ['__init__.py', 'detections.py', 'exceptions.py', 'schema.py', 'typing.py', 'utils.py'])
# ('dlt/common/storages', [], ['__init__.py', 'configuration.py', 'data_item_storage.py', 'exceptions.py', 'file_storage.py', 'fsspec_filesystem.py', 'live_schema_storage.py', 'load_storage.py', 'normalize_storage.py', 'schema_storage.py', 'transactional_file.py', 'versioned_storage.py'])
# ('dlt/destinations', ['athena', 'bigquery', 'duckdb', 'dummy', 'filesystem', 'motherduck', 'mssql', 'postgres', 'qdrant', 'redshift', 'snowflake', 'weaviate'], ['__init__.py', 'exceptions.py', 'insert_job_client.py', 'job_client_impl.py', 'job_impl.py', 'path_utils.py', 'sql_client.py', 'sql_jobs.py', 'type_mapping.py', 'typing.py'])
# ('dlt/destinations/athena', [], ['__init__.py', 'athena.py', 'configuration.py'])
# ('dlt/destinations/bigquery', [], ['README.md', '__init__.py', 'bigquery.py', 'configuration.py', 'sql_client.py'])
# ('dlt/destinations/duckdb', [], ['__init__.py', 'configuration.py', 'duck.py', 'sql_client.py'])
# ('dlt/destinations/dummy', [], ['__init__.py', 'configuration.py', 'dummy.py'])
# ('dlt/destinations/filesystem', [], ['__init__.py', 'configuration.py', 'filesystem.py'])
# ('dlt/destinations/motherduck', [], ['__init__.py', 'configuration.py', 'motherduck.py', 'sql_client.py'])
# ('dlt/destinations/mssql', [], ['README.md', '__init__.py', 'configuration.py', 'mssql.py', 'sql_client.py'])
# ('dlt/destinations/postgres', [], ['README.md', '__init__.py', 'configuration.py', 'postgres.py', 'sql_client.py'])
# ('dlt/destinations/qdrant', [], ['__init__.py', 'configuration.py', 'qdrant_adapter.py', 'qdrant_client.py'])
# ('dlt/destinations/redshift', [], ['README.md', '__init__.py', 'configuration.py', 'redshift.py'])
# ('dlt/destinations/snowflake', [], ['__init__.py', 'configuration.py', 'snowflake.py', 'sql_client.py'])
# ('dlt/destinations/weaviate', [], ['README.md', '__init__.py', 'ci_naming.py', 'configuration.py', 'exceptions.py', 'naming.py', 'weaviate_adapter.py', 'weaviate_client.py'])
# ('dlt/extract', ['incremental'], ['__init__.py', 'decorators.py', 'exceptions.py', 'extract.py', 'pipe.py', 'schema.py', 'source.py', 'typing.py', 'utils.py', 'validation.py', 'wrappers.py'])
# ('dlt/extract/incremental', [], ['__init__.py', 'exceptions.py', 'transform.py', 'typing.py'])
# ('dlt/helpers', ['dbt', 'dbt_cloud'], ['__init__.py', 'airflow_helper.py', 'streamlit_helper.py'])
# ('dlt/helpers/dbt', [], ['__init__.py', 'configuration.py', 'dbt_utils.py', 'exceptions.py', 'profiles.yml', 'runner.py'])
# ('dlt/helpers/dbt_cloud', [], ['__init__.py', 'client.py', 'configuration.py'])
# ('dlt/load', [], ['__init__.py', 'configuration.py', 'exceptions.py', 'load.py'])
# ('dlt/normalize', [], ['__init__.py', 'configuration.py', 'exceptions.py', 'items_normalizers.py', 'normalize.py'])
# ('dlt/pipeline', [], ['__init__.py', 'configuration.py', 'current.py', 'dbt.py', 'exceptions.py', 'helpers.py', 'mark.py', 'pipeline.py', 'progress.py', 'state_sync.py', 'trace.py', 'track.py', 'typing.py'])
# ('dlt/reflection', [], ['__init__.py', 'names.py', 'script_inspector.py', 'script_visitor.py'])
# ('dlt/sources', ['helpers'], ['__init__.py', 'config.py', 'credentials.py', 'filesystem.py'])
# ('dlt/sources/helpers', ['requests'], ['__init__.py', 'transform.py'])
# ('dlt/sources/helpers/requests', [], ['__init__.py', 'retry.py', 'session.py', 'typing.py'])
# ('docs', ['examples', 'technical', 'website'], ['__init__.py'])
# ('docs/examples', ['archive', 'chess', 'chess_production', 'connector_x_arrow', 'incremental_loading', 'nested_data', 'transformers', 'transformers_and_parallelism'], ['CONTRIBUTING.md'])
# ('docs/examples/archive', ['.dlt', 'credentials', 'data', 'examples', 'schemas', 'sources'], ['README.md', '__init__.py', '_helpers.py', 'dbt_run_jaffle.py', 'discord_iterator.py', 'google_drive_csv.py', 'google_sheets.py', 'quickstart.py', 'rasa_example.py', 'read_table.py', 'restore_pipeline.py', 'singer_tap_example.py', 'singer_tap_jsonl_example.py', 'sync_schema_example.py'])
# ('docs/examples/archive/.dlt', [], ['example.secrets.toml'])
# ('docs/examples/archive/credentials', ['.dlt'], ['__init__.py', 'explicit.py'])
# ('docs/examples/archive/credentials/.dlt', [], ['config.toml'])
# ('docs/examples/archive/data', ['rasa_trackers', 'singer_taps'], ['channels.json', 'demo_example.json', 'messages.json'])
# ('docs/examples/archive/data/rasa_trackers', [], ['2888158124550630_tracker.jsonl', '8629c904-0c26-4f0b-927b-14d48db43c28_tracker.jsonl'])
# ('docs/examples/archive/data/singer_taps', [], ['csv_catalog.json', 'model_annotations.csv', 'tap_google_sheet.jsonl', 'tap_hubspot.jsonl'])
# ('docs/examples/archive/examples', ['schemas'], [])
# ('docs/examples/archive/examples/schemas', [], ['dlt_quickstart.schema.yaml'])
# ('docs/examples/archive/schemas', [], ['__init__.py', 'discord.schema.yml', 'dlt_quickstart.schema.yaml', 'hubspot.schema.yaml', 'inferred_demo.schema.yml'])
# ('docs/examples/archive/sources', ['rasa'], ['__init__.py', 'google_sheets.py', 'jsonl.py', 'singer_tap.py', 'sql_query.py', 'stdout.py'])
# ('docs/examples/archive/sources/rasa', [], ['__init__.py', 'rasa.py', 'rasa.schema.yaml'])
# ('docs/examples/chess', ['.dlt', 'dbt_transform'], ['__init__.py', 'chess.py', 'chess_dbt.py'])
# ('docs/examples/chess/.dlt', [], ['config.toml'])
# ('docs/examples/chess/dbt_transform', ['analyses', 'macros', 'models', 'seeds', 'snapshots', 'tests'], ['.gitignore', 'dbt_project.yml', 'packages.yml'])
# ('docs/examples/chess/dbt_transform/analyses', [], ['.gitkeep'])
# ('docs/examples/chess/dbt_transform/macros', [], ['.gitkeep'])
# ('docs/examples/chess/dbt_transform/models', [], ['_dlt_loads.sql', 'load_ids.sql', 'schema.yml', 'sources.yml', 'view_player_games.sql'])
# ('docs/examples/chess/dbt_transform/seeds', [], ['.gitkeep'])
# ('docs/examples/chess/dbt_transform/snapshots', [], ['.gitkeep'])
# ('docs/examples/chess/dbt_transform/tests', [], ['.gitkeep'])
# ('docs/examples/chess_production', ['.dlt'], ['__init__.py', 'chess.py'])
# ('docs/examples/chess_production/.dlt', [], ['config.toml'])
# ('docs/examples/connector_x_arrow', [], ['__init__.py'])
# ('docs/examples/incremental_loading', ['.dlt'], ['__init__.py', 'zendesk.py'])
# ('docs/examples/incremental_loading/.dlt', [], ['config.toml', 'secrets.toml'])
# ('docs/examples/nested_data', ['.dlt'], ['__init__.py', 'nested_data.py'])
# ('docs/examples/nested_data/.dlt', [], ['config.toml', 'secrets.toml'])
# ('docs/examples/transformers', ['.dlt'], ['__init__.py', 'pokemon.py'])
# ('docs/examples/transformers/.dlt', [], ['config.toml'])
# ('docs/examples/transformers_and_parallelism', [], ['__init__.py'])
# ('docs/technical', [], ['README.md', 'create_pipeline.md', 'customization_and_hacking.md', 'general_usage.md', 'working_with_schemas.md'])
# ('docs/website', ['blog', 'docs', 'src', 'static', 'tools'], ['.gitignore', '.npmrc', 'README.md', '__init__.py', 'babel.config.js', 'docusaurus.config.js', 'netlify.toml', 'package-lock.json', 'package.json', 'pydoc-markdown.yml', 'pydoc_markdown_dlt.py', 'requirements.txt', 'sidebars.js'])
# ('docs/website/blog', [], ['2023-02-16-dlthub-mission.md', '2023-02-22-dlthub-who-we-serve.md', '2023-03-09-duckdb-1M-downloads-users.mdx', '2023-03-16-is-duckdb-a-database-for-ducks.mdx', '2023-04-27-ga4-internal-dashboard-demo.md', '2023-05-15-hacker-news-gpt-4-dashboard-demo.md', '2023-05-25-postgresql-bigquery-metabase-demo.md', '2023-05-26-structured-data-lakes-through-schema-evolution-next-generation-data-platform.md', '2023-06-05-google-sheets-to-data-warehouse-pipeline.md', '2023-06-10-schema-evolution.md', '2023-06-14-dlthub-gpt-accelerated learning_01.md', '2023-06-15-automating-data-engineers.md', '2023-06-20-dlthub-gptquestion1-.md', '2023-06-21-open-api-spec-for-dlt-init.md', '2023-06-26-dlthub-gptquestion2.md', '2023-08-14-dlt-motherduck-blog.md', '2023-08-21-dlt-lineage-support.md', '2023-08-24-dlt-etlt.md', '2023-09-05-mongo-etl.md', '2023-09-20-data-engineering-cv.md', '2023-09-26-verba-dlt-zendesk.md', '2023-10-06-dlt-holistics.md', '2023-10-09-dlt-ops-startups.md', '2023-10-10-data-product-docs.md', '2023-10-16-first-data-warehouse.md', '2023-10-19-dbt-runners.md', '2023-10-23-arrow-loading.md', '2023-10-25-dlt-deepnote.md', '2023-10-26-dlt-prefect.md', '2023-10-30-data-modelling-tools.md', '2023-11-01-dlt-dagster.md', '2023-11-08-solving-ingestion.md', '2023-11-22-dlt-webhooks-event-based-ingestion.md', '2023-11-27-dlt-data-lineage.md', '2023-11-29-exploring-data-replication-of-sap-hana-to-snowflake-using-dlt.md', '2023-12-01-dlt-kestra-demo.md', 'authors.yml'])
# ('docs/website/docs', ['.dlt', 'assets', 'dlt-ecosystem', 'examples', 'general-usage', 'reference', 'running-in-production', 'walkthroughs'], ['__init__.py', 'build-a-pipeline-tutorial.md', 'conftest.py', 'getting-started-snippets.py', 'getting-started.md', 'intro-snippets.py', 'intro.md', 'utils.py'])
# ('docs/website/docs/.dlt', [], ['config.toml'])
# ('docs/website/docs/assets', ['invoices'], ['json_file.json'])
# ('docs/website/docs/assets/invoices', [], ['invoice_2.txt', 'invoice_20230831-p1.pdf'])
# ('docs/website/docs/dlt-ecosystem', ['destinations', 'file-formats', 'transformations', 'verified-sources', 'visualizations'], ['staging.md'])
# ('docs/website/docs/dlt-ecosystem/destinations', [], ['athena.md', 'bigquery.md', 'duckdb.md', 'filesystem.md', 'index.md', 'motherduck.md', 'mssql.md', 'postgres.md', 'qdrant.md', 'redshift.md', 'snowflake.md', 'weaviate.md'])
# ('docs/website/docs/dlt-ecosystem/file-formats', [], ['insert-format.md', 'jsonl.md', 'parquet.md'])
# ('docs/website/docs/dlt-ecosystem/transformations', ['dbt'], ['pandas.md', 'sql.md'])
# ('docs/website/docs/dlt-ecosystem/transformations/dbt', [], ['__init__.py', 'dbt-snippets.py', 'dbt.md', 'dbt_cloud.md', 'profiles.yml'])
# ('docs/website/docs/dlt-ecosystem/verified-sources', ['docs_images'], ['airtable.md', 'amazon_kinesis.md', 'arrow-pandas.md', 'asana.md', 'chess.md', 'facebook_ads.md', 'filesystem.md', 'github.md', 'google_analytics.md', 'google_sheets.md', 'hubspot.md', 'inbox.md', 'index.md', 'jira.md', 'matomo.md', 'mongodb.md', 'mux.md', 'notion.md', 'personio.md', 'pipedrive.md', 'salesforce.md', 'shopify.md', 'slack.md', 'sql_database.md', 'strapi.md', 'stripe.md', 'workable.md', 'zendesk.md'])
# ('docs/website/docs/dlt-ecosystem/verified-sources/docs_images', [], ['Add_people.png', 'Airtable_ids.jpeg', 'GA4_Property_ID_size.png', 'Matomo_name_and_id.png', 'Notion_Database_2.jpeg', 'Share_button.png', 'Zendesk_Admin.jpeg', 'Zendesk_chat_access_token.jpg'])
# ('docs/website/docs/dlt-ecosystem/visualizations', [], ['exploring-the-data.md'])
# ('docs/website/docs/examples', ['chess_production', 'connector_x_arrow', 'incremental_loading', 'nested_data', 'transformers'], ['_examples-header.md', 'index.md'])
# ('docs/website/docs/examples/chess_production', ['code'], ['__init__.py', 'index.md'])
# ('docs/website/docs/examples/chess_production/code', ['.dlt'], ['__init__.py', 'chess-snippets.py'])
# ('docs/website/docs/examples/chess_production/code/.dlt', [], ['config.toml'])
# ('docs/website/docs/examples/connector_x_arrow', ['code'], ['__init__.py', 'index.md'])
# ('docs/website/docs/examples/connector_x_arrow/code', [], ['__init__.py', 'load_arrow-snippets.py'])
# ('docs/website/docs/examples/incremental_loading', ['code'], ['__init__.py', 'index.md'])
# ('docs/website/docs/examples/incremental_loading/code', ['.dlt'], ['__init__.py', 'zendesk-snippets.py'])
# ('docs/website/docs/examples/incremental_loading/code/.dlt', [], ['config.toml', 'secrets.toml'])
# ('docs/website/docs/examples/nested_data', ['code'], ['__init__.py', 'index.md'])
# ('docs/website/docs/examples/nested_data/code', ['.dlt'], ['__init__.py', 'nested_data-snippets.py'])
# ('docs/website/docs/examples/nested_data/code/.dlt', [], ['config.toml', 'secrets.toml'])
# ('docs/website/docs/examples/transformers', ['code'], ['__init__.py', 'index.md'])
# ('docs/website/docs/examples/transformers/code', ['.dlt'], ['__init__.py', 'pokemon-snippets.py'])
# ('docs/website/docs/examples/transformers/code/.dlt', [], ['config.toml'])
# ('docs/website/docs/general-usage', ['credentials', 'customising-pipelines'], ['destination-tables.md', 'full-loading.md', 'glossary.md', 'incremental-loading.md', 'pipeline.md', 'resource.md', 'schema.md', 'source.md', 'state.md'])
# ('docs/website/docs/general-usage/credentials', [], ['config_providers.md', 'config_specs.md', 'configuration.md'])
# ('docs/website/docs/general-usage/customising-pipelines', [], ['pseudonymizing_columns.md', 'renaming_columns.md'])
# ('docs/website/docs/reference', ['explainers', 'performance_snippets'], ['__init__.py', 'command-line-interface.md', 'installation.md', 'performance.md', 'telemetry.md'])
# ('docs/website/docs/reference/explainers', [], ['airflow-gcp-cloud-composer.md', 'how-dlt-works.md'])
# ('docs/website/docs/reference/performance_snippets', ['.dlt'], ['__init__.py', 'performance-snippets.py', 'toml-snippets.toml'])
# ('docs/website/docs/reference/performance_snippets/.dlt', [], ['config.toml'])
# ('docs/website/docs/running-in-production', ['images'], ['alerting.md', 'monitoring.md', 'running.md', 'tracing.md'])
# ('docs/website/docs/running-in-production/images', [], ['airflow_dag_tasks.png', 'airflow_dags.png', 'airflow_slack_notification.png', 'github_actions_workflow_dag.png', 'github_actions_workflows.png'])
# ('docs/website/docs/walkthroughs', ['deploy-a-pipeline'], ['add-a-verified-source.md', 'add_credentials.md', 'adjust-a-schema.md', 'create-a-pipeline.md', 'create-new-destination.md', 'run-a-pipeline.md', 'share-a-dataset.md', 'zendesk-weaviate.md'])
# ('docs/website/docs/walkthroughs/deploy-a-pipeline', ['images'], ['deploy-gcp-cloud-function-as-webhook.md', 'deploy-with-airflow-composer.md', 'deploy-with-github-actions.md', 'deploy-with-google-cloud-functions.md'])
# ('docs/website/docs/walkthroughs/deploy-a-pipeline/images', [], ['add-credential.png', 'dag-folder.png', 'run-trigger.png'])
# ('docs/website/src', ['css', 'theme'], [])
# ('docs/website/src/css', [], ['custom.css'])
# ('docs/website/src/theme', [], ['DLTExampleHeader.tsx', 'MDXComponents.js', 'Root.js'])
# ('docs/website/static', ['img'], ['.nojekyll'])
# ('docs/website/static/img', [], ['CO-Blue.svg', 'CO-White.svg', 'Concepts - Active.svg', 'Concepts - Inactive.svg', 'Customization-Active-1.svg', 'Customization-Active.svg', 'Customization-Inactive-1.svg', 'Customization-Inactive.svg', 'Destinations-Active-1.svg', 'Destinations-Active.svg', 'Destinations-Inactive-1.svg', 'Destinations-Inactive.svg', 'GeneralUsage-Active-1.svg', 'GeneralUsage-Active.svg', 'GeneralUsage-Inactive-1.svg', 'GeneralUsage-Inactive.svg', 'GettingStarted-Active-1.svg', 'GettingStarted-Active.svg', 'GettingStarted-Inactive-1.svg', 'GettingStarted-Inactive.svg', 'GithubDark.svg', 'GithubLight.svg', 'Holistics_new.gif', 'Howdltworks-Active-1.svg', 'Howdltworks-Active.svg', 'Howdltworks-Inactive-1.svg', 'Howdltworks-Inactive.svg', 'Installation-Active-1.svg', 'Installation-Active.svg', 'Installation-Inactive-1.svg', 'Installation-Inactive.svg', 'Introduction-Active-1.svg', 'Introduction-Active.svg', 'Introduction-Inactive-1.svg', 'Introduction-Inactive.svg', 'Marcin-dltHub-DuckDB-DuckCon-Brussels.jpg', 'Pipelines-Active-1.svg', 'Pipelines-Active.svg', 'Pipelines-Inactive-1.svg', 'Pipelines-Inactive.svg', 'Reference-Active-1.svg', 'Reference-Active.svg', 'Reference-Inactive-1.svg', 'Reference-Inactive.svg', 'RunningInProduction-Active-1.svg', 'RunningInProduction-Active.svg', 'RunningInProduction-Inactive-1.svg', 'RunningInProduction-Inactive.svg', 'SlackDark.svg', 'SlackLight.svg', 'UserGuide-Active-1.svg', 'UserGuide-Active.svg', 'UserGuide-Inactive-1.svg', 'UserGuide-Inactive.svg', 'UsingLoadedData-Active-1.svg', 'UsingLoadedData-Active.svg', 'UsingLoadedData-Inactive-1.svg', 'UsingLoadedData-Inactive.svg', 'Walkthrough-Active-1.svg', 'Walkthrough-Active.svg', 'Walkthrough-Inactive-1.svg', 'Walkthrough-Inactive.svg', 'add-credential.png', 'add-package.png', 'architecture-diagram.png', 'arrow_30x_faster.png', 'blog-ingestion-etl-tools-users.png', 'blog-modelling-data-dictionaries-gooddata.png', 'blog-modelling-data-dictionaries-metabase.png', 'blog-modelling-data-dictionaries-pbi.png', 'blog-modelling-data-types-power-bi.png', 'blog-modelling-granularity-gooddata.png', 'blog-modelling-granularity-metabase.png', 'blog-modelling-granularity-pbi.png', 'blog-modelling-language-gooddata.png', 'blog-modelling-language-metabase.png', 'blog-modelling-language-pbi.png', 'blog-modelling-metrics-gooddata.png', 'blog-modelling-metrics-metabase.png', 'blog-modelling-metrics-pbi.png', 'blog-modelling-refresh-gooddata.png', 'blog-modelling-refresh-metabase.png', 'blog-modelling-refresh-pbi.png', 'blog-modelling-table-prop-gooddata.png', 'blog-modelling-table-prop-metabase.png', 'blog-modelling-table-prop-pbi.png', 'blog-modelling-table-rel-gooddata.png', 'blog-modelling-table-rel-metabase.png', 'blog-modelling-table-rel-pbi.png', 'blog-what_would_drake_do.png', 'blog_deepnote_animation.gif', 'blog_deepnote_chart.png', 'blog_deepnote_improved_flow.png', 'blog_deepnote_usual_flow.png', 'blog_gpt_1.jpg', 'blog_gpt_QA2.jpg', 'bucket-details.png', 'chatgptQ1.png', 'chatgptQ2..png', 'dall-e-de-cv.png', 'data-dumpster.png', 'data-types-gooddata.png', 'data-types-metabase.png', 'dlt-business-knowledge-retrieval-augmented-generation-diagram.png', 'dlt-high-level.png', 'dlt-logo-old.svg', 'dlt-logo.svg', 'dlt-motherduck-dashboard-1.png', 'dlt-motherduck-dashboard-2.png', 'dlt-motherduck-dashboard-3.png', 'dlt-motherduck-dashboard-4.png', 'dlt-motherduck-duckdb-explore.png', 'dlt-motherduck-local-workflow.png', 'dlt-motherduck-logos.png', 'dlt-motherduck-nested-bigquery.png', 'dlt-motherduck-normalized-bigquery.png', 'dlt-motherduck-production-workflow.png', 'dlt-motherduck-share.png', 'dlt-pacman.gif', 'dlt-weaviate-verba-ui-1.png', 'dlt-weaviate-verba-ui-2.png', 'dlt.png', 'dlt_holistics_bigquery_data.png', 'dlt_holistics_bigquery_table.png', 'dlt_holistics_overview.jpg', 'dlthelp.jpg', 'dlthub-logo.png', 'docs_where_does_dlt_fit_in_ETL_pipeline.png', 'docusaurus.png', 'experiment3_dashboard_orders_chart.png', 'experiment3_dashb ...
# ('docs/website/tools', [], ['update_snippets.js', 'update_version_env.js'])
# ('tests', ['.dlt', 'cli', 'common', 'destinations', 'extract', 'helpers', 'load', 'normalize', 'pipeline', 'reflection', 'sources', 'tools'], ['.example.env', '__init__.py', 'cases.py', 'conftest.py', 'utils.py'])
# ('tests/.dlt', [], ['config.toml'])
# ('tests/cli', ['cases', 'common'], ['__init__.py', 'conftest.py', 'test_config_toml_writer.py', 'test_deploy_command.py', 'test_init_command.py', 'test_pipeline_command.py', 'utils.py'])
# ('tests/cli/cases', ['deploy_pipeline'], [])
# ('tests/cli/cases/deploy_pipeline', ['.dlt'], ['.gitignore', 'README.md', '__init__.py', 'debug_pipeline.py', 'dummy_pipeline.py', 'requirements.txt'])
# ('tests/cli/cases/deploy_pipeline/.dlt', [], ['config.toml', 'secrets.toml', 'secrets.toml.ci'])
# ('tests/cli/common', [], ['__init__.py', 'test_cli_invoke.py', 'test_telemetry_command.py'])
# ('tests/common', ['cases', 'configuration', 'data_writers', 'normalizers', 'reflection', 'runners', 'runtime', 'schema', 'scripts', 'storages'], ['__init__.py', 'test_arithmetics.py', 'test_destination.py', 'test_git.py', 'test_json.py', 'test_pipeline_state.py', 'test_pyarrow.py', 'test_pydantic.py', 'test_time.py', 'test_typing.py', 'test_utils.py', 'test_validation.py', 'test_version.py', 'test_wei.py', 'utils.py'])
# ('tests/common/cases', ['configuration', 'modules', 'schemas', 'secret-kube', 'secrets'], ['level-dragon-333019-707809ee408a.json.b64', 'mod_bot_case.json', 'oauth_client_secret_929384042504.json', 'pua_encoded_row.json', 'rasa_event_bot_metadata.json', 'secret-value', 'simple_row.json', 'weird_rows.json'])
# ('tests/common/cases/configuration', ['.dlt', '.wrong.dlt', 'dlt_home'], [])
# ('tests/common/cases/configuration/.dlt', [], ['config.toml', 'secrets.toml'])
# ('tests/common/cases/configuration/.wrong.dlt', [], ['config.toml'])
# ('tests/common/cases/configuration/dlt_home', [], ['config.toml'])
# ('tests/common/cases/modules', [], ['__init__.py', 'uniq_mod_121.py'])
# ('tests/common/cases/schemas', ['eth', 'ev1', 'ev2', 'github', 'local', 'rasa', 'sheets'], [])
# ('tests/common/cases/schemas/eth', [], ['ethereum_schema_v3.yml', 'ethereum_schema_v4.yml', 'ethereum_schema_v5.yml', 'ethereum_schema_v6.yml'])
# ('tests/common/cases/schemas/ev1', [], ['event.schema.7z', 'event.schema.bak.json.gz', 'event.schema.json', 'model.schema.json'])
# ('tests/common/cases/schemas/ev2', [], ['event.schema.json'])
# ('tests/common/cases/schemas/github', [], ['issues.schema.json'])
# ('tests/common/cases/schemas/local', [], ['event.schema.json', 'event.schema.yaml', 'name_mismatch.schema.yaml'])
# ('tests/common/cases/schemas/rasa', [], ['event.schema.json', 'model.schema.json'])
# ('tests/common/cases/schemas/sheets', [], ['google_spreadsheet_v4.schema.json'])
# ('tests/common/cases/secret-kube', [], ['secret-kube'])
# ('tests/common/cases/secrets', [], ['deploy-key', 'deploy_key.pub', 'encrypted-private-key', 'encrypted-private-key-base64'])
# ('tests/common/configuration', [], ['__init__.py', 'test_accessors.py', 'test_configuration.py', 'test_container.py', 'test_credentials.py', 'test_environ_provider.py', 'test_inject.py', 'test_providers.py', 'test_sections.py', 'test_spec_union.py', 'test_toml_provider.py', 'utils.py'])
# ('tests/common/data_writers', [], ['__init__.py', 'test_buffered_writer.py', 'test_data_writers.py', 'test_parquet_writer.py'])
# ('tests/common/normalizers', [], ['__init__.py', 'custom_normalizers.py', 'test_import_normalizers.py', 'test_json_relational.py', 'test_naming.py', 'test_naming_duck_case.py', 'test_naming_snake_case.py'])
# ('tests/common/reflection', [], ['__init__.py', 'test_reflect_spec.py'])
# ('tests/common/runners', [], ['__init__.py', 'test_pipes.py', 'test_runnable.py', 'test_runners.py', 'test_venv.py', 'utils.py'])
# ('tests/common/runtime', [], ['__init__.py', 'test_collector.py', 'test_logging.py', 'test_signals.py', 'test_telemetry.py', 'utils.py'])
# ('tests/common/schema', [], ['__init__.py', 'test_coercion.py', 'test_detections.py', 'test_filtering.py', 'test_inference.py', 'test_merges.py', 'test_schema.py', 'test_versioning.py'])
# ('tests/common/scripts', [], ['__init__.py', 'args.py', 'counter.py', 'cwd.py', 'empty.py', 'environ.py', 'long_lines.py', 'long_lines_fails.py', 'no_stdout_exception.py', 'no_stdout_no_stderr_with_fail.py', 'raises.py', 'raising_counter.py', 'stdout_encode_exception.py', 'stdout_encode_result.py', 'stdout_encode_unpicklable.py'])
# ('tests/common/storages', ['samples'], ['__init__.py', 'test_file_storage.py', 'test_loader_storage.py', 'test_local_filesystem.py', 'test_normalize_storage.py', 'test_schema_storage.py', 'test_transactional_file.py', 'test_versioned_storage.py', 'utils.py'])
# ('tests/common/storages/samples', ['csv', 'jsonl', 'met_csv', 'parquet'], ['sample.txt'])
# ('tests/common/storages/samples/csv', [], ['freshman_kgs.csv', 'freshman_lbs.csv', 'mlb_players.csv', 'mlb_teams_2012.csv'])
# ('tests/common/storages/samples/jsonl', [], ['mlb_players.jsonl'])
# ('tests/common/storages/samples/met_csv', ['A801', 'A803'], [])
# ('tests/common/storages/samples/met_csv/A801', [], ['A881_20230920.csv'])
# ('tests/common/storages/samples/met_csv/A803', [], ['A803_20230919.csv', 'A803_20230920.csv'])
# ('tests/common/storages/samples/parquet', [], ['mlb_players.parquet'])
# ('tests/destinations', [], ['__init__.py', 'test_path_utils.py'])
# ('tests/extract', ['cases'], ['__init__.py', 'conftest.py', 'test_decorators.py', 'test_extract.py', 'test_extract_pipe.py', 'test_incremental.py', 'test_sources.py', 'test_utils.py', 'test_validation.py', 'utils.py'])
# ('tests/extract/cases', ['eth_source', 'section_source'], ['__init__.py'])
# ('tests/extract/cases/eth_source', [], ['__init__.py', 'ethereum.schema.yaml', 'source.py'])
# ('tests/extract/cases/section_source', [], ['__init__.py', 'external_resources.py', 'named_module.py'])
# ('tests/helpers', ['airflow_tests', 'dbt_cloud_tests', 'dbt_tests', 'providers', 'streamlit_tests'], [])
# ('tests/helpers/airflow_tests', [], ['__init__.py', 'conftest.py', 'test_airflow_provider.py', 'test_airflow_wrapper.py', 'test_join_airflow_scheduler.py', 'utils.py'])
# ('tests/helpers/dbt_cloud_tests', [], ['__init__.py', 'test_dbt_cloud.py'])
# ('tests/helpers/dbt_tests', ['cases', 'local'], ['__init__.py', 'test_runner_dbt_versions.py', 'utils.py'])
# ('tests/helpers/dbt_tests/cases', [], ['jaffle_customers_incremental.sql', 'jaffle_customers_incremental_new_column.sql', 'jaffle_customers_with_error.sql', 'profiles.yml', 'profiles_invalid_credentials.yml', 'run_execution_incremental_fail.pickle.hex', 'run_result_incremental_fail.pickle.hex'])
# ('tests/helpers/dbt_tests/local', [], ['__init__.py', 'test_dbt_utils.py', 'test_runner_destinations.py', 'utils.py'])
# ('tests/helpers/providers', [], ['__init__.py', 'test_google_secrets_provider.py'])
# ('tests/helpers/streamlit_tests', [], ['__init__.py', 'test_streamlit_show_resources.py'])
# ('tests/load', ['athena_iceberg', 'bigquery', 'cases', 'duckdb', 'filesystem', 'mssql', 'pipeline', 'postgres', 'qdrant', 'redshift', 'snowflake', 'weaviate'], ['__init__.py', 'conftest.py', 'test_dummy_client.py', 'test_insert_job_client.py', 'test_job_client.py', 'test_sql_client.py', 'utils.py'])
# ('tests/load/athena_iceberg', [], ['__init__.py', 'test_athena_iceberg.py'])
# ('tests/load/bigquery', [], ['__init__.py', 'test_bigquery_client.py', 'test_bigquery_table_builder.py'])
# ('tests/load/cases', ['loading'], ['__init__.py', 'event.schema.json', 'event_user.json', 'fake_destination.py', 'long_column_name.json', 'long_table_name.json'])
# ('tests/load/cases/loading', [], ['event_bot.181291798a78198.0.unsupported_format', 'event_bot.b1d32c6660b242aaabbf3fc27245b7e6.0.insert_values', 'event_loop_interrupted.839c6e6b514e427687586ccc65bf133f.0.jsonl', 'event_user.839c6e6b514e427687586ccc65bf133f.0.jsonl', 'event_user.b1d32c6660b242aaabbf3fc27245b7e6.0.insert_values', 'schema.json', 'schema_updates.json'])
# ('tests/load/duckdb', [], ['__init__.py', 'test_duckdb_client.py', 'test_duckdb_table_builder.py', 'test_motherduck_client.py'])
# ('tests/load/filesystem', [], ['__init__.py', 'test_aws_credentials.py', 'test_azure_credentials.py', 'test_filesystem_client.py', 'test_filesystem_common.py', 'utils.py'])
# ('tests/load/mssql', [], ['__init__.py', 'test_mssql_credentials.py', 'test_mssql_table_builder.py'])
# ('tests/load/pipeline', [], ['__init__.py', 'conftest.py', 'test_arrow_loading.py', 'test_athena.py', 'test_dbt_helper.py', 'test_drop.py', 'test_duckdb.py', 'test_filesystem_pipeline.py', 'test_merge_disposition.py', 'test_pipelines.py', 'test_redshift.py', 'test_replace_disposition.py', 'test_restore_state.py', 'test_stage_loading.py', 'test_write_disposition_changes.py', 'utils.py'])
# ('tests/load/postgres', ['postgres'], ['__init__.py', 'docker-compose.yml', 'postgres.env', 'test_postgres_client.py', 'test_postgres_table_builder.py'])
# ('tests/load/postgres/postgres', [], ['01_init.sql', 'Dockerfile'])
# ('tests/load/qdrant', [], ['__init__.py', 'test_pipeline.py', 'utils.py'])
# ('tests/load/redshift', [], ['__init__.py', 'setup_db.sql', 'test_redshift_client.py', 'test_redshift_table_builder.py'])
# ('tests/load/snowflake', [], ['__init__.py', 'test_snowflake_configuration.py', 'test_snowflake_table_builder.py'])
# ('tests/load/weaviate', [], ['__init__.py', 'test_naming.py', 'test_pipeline.py', 'test_weaviate_client.py', 'utils.py'])
# ('tests/normalize', ['cases'], ['__init__.py', 'mock_rasa_json_normalizer.py', 'test_normalize.py', 'utils.py'])
# ('tests/normalize/cases', ['schemas'], ['ethereum.blocks.9c1d9b504ea240a482b007788d5cd61c_2.json', 'event.event.bot_load_metadata_2987398237498798.json', 'event.event.many_load_2.json', 'event.event.slot_session_metadata_1.json', 'event.event.user_load_1.json', 'event.event.user_load_v228_1.json', 'github.events.load_page_1_duck.json', 'github.issues.load_page_5_duck.json', 'rasa_event_bot_metadata.json', 'rasa_event_bot_template.json', 'rasa_user_event.json'])
# ('tests/normalize/cases/schemas', [], ['ethereum.schema.json', 'event.schema.json'])
# ('tests/pipeline', ['cases'], ['__init__.py', 'conftest.py', 'test_arrow_sources.py', 'test_dlt_versions.py', 'test_pipeline.py', 'test_pipeline_file_format_resolver.py', 'test_pipeline_state.py', 'test_pipeline_trace.py', 'test_schema_updates.py', 'utils.py'])
# ('tests/pipeline/cases', ['github_pipeline', 'state'], [])
# ('tests/pipeline/cases/github_pipeline', ['.dlt'], ['__init__.py', 'github_extract.py', 'github_load.py', 'github_pipeline.py'])
# ('tests/pipeline/cases/github_pipeline/.dlt', [], ['config.toml'])
# ('tests/pipeline/cases/state', [], ['state.v1.json'])
# ('tests/reflection', ['module_cases'], ['__init__.py', 'test_script_inspector.py'])
# ('tests/reflection/module_cases', ['stripe_analytics'], ['__init__.py', 'all_imports.py', 'dlt_import_exception.py', 'executes_resource.py', 'import_as_type.py', 'no_pkg.py', 'raises.py', 'stripe_analytics_pipeline.py', 'syntax_error.py'])
# ('tests/reflection/module_cases/stripe_analytics', [], ['__init__.py', 'helpers.py', 'stripe_analytics.py'])
# ('tests/sources', ['helpers'], ['__init__.py'])
# ('tests/sources/helpers', [], ['__init__.py', 'test_requests.py'])
# ('tests/tools', [], ['__init__.py', 'clean_redshift.py', 'create_storages.py', 'early_dependencies.py'])

# %%
fs_gitpythonfs.find("") # , include_committed_date=True)
# Out:
# ['.dockerignore',
#  '.editorconfig',
#  '.github/ISSUE_TEMPLATE/bug_report.yml',
#  '.github/ISSUE_TEMPLATE/config.yml',
#  '.github/ISSUE_TEMPLATE/feature_request.yml',
#  '.github/PULL_REQUEST_TEMPLATE.md',
#  '.github/weaviate-compose.yml',
#  '.github/workflows/get_docs_changes.yml',
#  '.github/workflows/lint.yml',
#  '.github/workflows/test_airflow.yml',
#  '.github/workflows/test_build_images.yml',
#  '.github/workflows/test_common.yml',
#  '.github/workflows/test_dbt_cloud.yml',
#  '.github/workflows/test_dbt_runner.yml',
#  '.github/workflows/test_destination_athena.yml',
#  '.github/workflows/test_destination_athena_iceberg.yml',
#  '.github/workflows/test_destination_bigquery.yml',
#  '.github/workflows/test_destination_mssql.yml',
#  '.github/workflows/test_destination_qdrant.yml',
#  '.github/workflows/test_destination_snowflake.yml',
#  '.github/workflows/test_destination_synapse.yml',
#  '.github/workflows/test_destination_weaviate.yml',
#  '.github/workflows/test_destinations.yml',
#  '.github/workflows/test_doc_snippets.yml',
#  '.github/workflows/test_local_destinations.yml',
#  '.gitignore',
#  'CONTRIBUTING.md',
#  'LICENSE.txt',
#  'Makefile',
#  'README.md',
#  'check-package.sh',
#  'compiled_packages.txt',
#  'deploy/dlt/Dockerfile',
#  'deploy/dlt/Dockerfile.airflow',
#  'deploy/dlt/README.md',
#  'dlt/__init__.py',
#  'dlt/cli/__init__.py',
#  'dlt/cli/_dlt.py',
#  'dlt/cli/config_toml_writer.py',
#  'dlt/cli/deploy_command.py',
#  'dlt/cli/deploy_command_helpers.py',
#  'dlt/cli/echo.py',
#  'dlt/cli/exceptions.py',
#  'dlt/cli/init_command.py',
#  'dlt/cli/pipeline_command.py',
#  'dlt/cli/pipeline_files.py',
#  'dlt/cli/requirements.py',
#  'dlt/cli/source_detection.py',
#  'dlt/cli/telemetry_command.py',
#  'dlt/cli/utils.py',
#  'dlt/common/__init__.py',
#  'dlt/common/arithmetics.py',
#  'dlt/common/configuration/__init__.py',
#  'dlt/common/configuration/accessors.py',
#  'dlt/common/configuration/container.py',
#  'dlt/common/configuration/exceptions.py',
#  'dlt/common/configuration/inject.py',
#  'dlt/common/configuration/paths.py',
#  'dlt/common/configuration/providers/__init__.py',
#  'dlt/common/configuration/providers/airflow.py',
#  'dlt/common/configuration/providers/context.py',
#  'dlt/common/configuration/providers/dictionary.py',
#  'dlt/common/configuration/providers/environ.py',
#  'dlt/common/configuration/providers/google_secrets.py',
#  'dlt/common/configuration/providers/provider.py',
#  'dlt/common/configuration/providers/toml.py',
#  'dlt/common/configuration/resolve.py',
#  'dlt/common/configuration/specs/__init__.py',
#  'dlt/common/configuration/specs/api_credentials.py',
#  'dlt/common/configuration/specs/aws_credentials.py',
#  'dlt/common/configuration/specs/azure_credentials.py',
#  'dlt/common/configuration/specs/base_configuration.py',
#  'dlt/common/configuration/specs/config_providers_context.py',
#  'dlt/common/configuration/specs/config_section_context.py',
#  'dlt/common/configuration/specs/connection_string_credentials.py',
#  'dlt/common/configuration/specs/exceptions.py',
#  'dlt/common/configuration/specs/gcp_credentials.py',
#  'dlt/common/configuration/specs/known_sections.py',
#  'dlt/common/configuration/specs/run_configuration.py',
#  'dlt/common/configuration/utils.py',
#  'dlt/common/data_types/__init__.py',
#  'dlt/common/data_types/type_helpers.py',
#  'dlt/common/data_types/typing.py',
#  'dlt/common/data_writers/__init__.py',
#  'dlt/common/data_writers/buffered.py',
#  'dlt/common/data_writers/escape.py',
#  'dlt/common/data_writers/exceptions.py',
#  'dlt/common/data_writers/writers.py',
#  'dlt/common/destination/__init__.py',
#  'dlt/common/destination/capabilities.py',
#  'dlt/common/destination/reference.py',
#  'dlt/common/exceptions.py',
#  'dlt/common/git.py',
#  'dlt/common/json/__init__.py',
#  'dlt/common/json/_orjson.py',
#  'dlt/common/json/_simplejson.py',
#  'dlt/common/jsonpath.py',
#  'dlt/common/libs/__init__.py',
#  'dlt/common/libs/pandas.py',
#  'dlt/common/libs/pyarrow.py',
#  'dlt/common/libs/pydantic.py',
#  'dlt/common/normalizers/__init__.py',
#  'dlt/common/normalizers/configuration.py',
#  'dlt/common/normalizers/exceptions.py',
#  'dlt/common/normalizers/json/__init__.py',
#  'dlt/common/normalizers/json/relational.py',
#  'dlt/common/normalizers/naming/__init__.py',
#  'dlt/common/normalizers/naming/direct.py',
#  'dlt/common/normalizers/naming/duck_case.py',
#  'dlt/common/normalizers/naming/exceptions.py',
#  'dlt/common/normalizers/naming/naming.py',
#  'dlt/common/normalizers/naming/snake_case.py',
#  'dlt/common/normalizers/typing.py',
#  'dlt/common/normalizers/utils.py',
#  'dlt/common/pendulum.py',
#  'dlt/common/pipeline.py',
#  'dlt/common/reflection/__init__.py',
#  'dlt/common/reflection/function_visitor.py',
#  'dlt/common/reflection/spec.py',
#  'dlt/common/reflection/utils.py',
#  'dlt/common/runners/__init__.py',
#  'dlt/common/runners/configuration.py',
#  'dlt/common/runners/pool_runner.py',
#  'dlt/common/runners/runnable.py',
#  'dlt/common/runners/stdout.py',
#  'dlt/common/runners/synth_pickle.py',
#  'dlt/common/runners/typing.py',
#  'dlt/common/runners/venv.py',
#  'dlt/common/runtime/__init__.py',
#  'dlt/common/runtime/collector.py',
#  'dlt/common/runtime/exec_info.py',
#  'dlt/common/runtime/init.py',
#  'dlt/common/runtime/json_logging.py',
#  'dlt/common/runtime/logger.py',
#  'dlt/common/runtime/prometheus.py',
#  'dlt/common/runtime/segment.py',
#  'dlt/common/runtime/sentry.py',
#  'dlt/common/runtime/signals.py',
#  'dlt/common/runtime/slack.py',
#  'dlt/common/runtime/telemetry.py',
#  'dlt/common/schema/__init__.py',
#  'dlt/common/schema/detections.py',
#  'dlt/common/schema/exceptions.py',
#  'dlt/common/schema/schema.py',
#  'dlt/common/schema/typing.py',
#  'dlt/common/schema/utils.py',
#  'dlt/common/source.py',
#  'dlt/common/storages/__init__.py',
#  'dlt/common/storages/configuration.py',
#  'dlt/common/storages/data_item_storage.py',
#  'dlt/common/storages/exceptions.py',
#  'dlt/common/storages/file_storage.py',
#  'dlt/common/storages/fsspec_filesystem.py',
#  'dlt/common/storages/live_schema_storage.py',
#  'dlt/common/storages/load_storage.py',
#  'dlt/common/storages/normalize_storage.py',
#  'dlt/common/storages/schema_storage.py',
#  'dlt/common/storages/transactional_file.py',
#  'dlt/common/storages/versioned_storage.py',
#  'dlt/common/time.py',
#  'dlt/common/typing.py',
#  'dlt/common/utils.py',
#  'dlt/common/validation.py',
#  'dlt/common/wei.py',
#  'dlt/destinations/__init__.py',
#  'dlt/destinations/athena/__init__.py',
#  'dlt/destinations/athena/athena.py',
#  'dlt/destinations/athena/configuration.py',
#  'dlt/destinations/bigquery/README.md',
#  'dlt/destinations/bigquery/__init__.py',
#  'dlt/destinations/bigquery/bigquery.py',
#  'dlt/destinations/bigquery/configuration.py',
#  'dlt/destinations/bigquery/sql_client.py',
#  'dlt/destinations/duckdb/__init__.py',
#  'dlt/destinations/duckdb/configuration.py',
#  'dlt/destinations/duckdb/duck.py',
#  'dlt/destinations/duckdb/sql_client.py',
#  'dlt/destinations/dummy/__init__.py',
#  'dlt/destinations/dummy/configuration.py',
#  'dlt/destinations/dummy/dummy.py',
#  'dlt/destinations/exceptions.py',
#  'dlt/destinations/filesystem/__init__.py',
#  'dlt/destinations/filesystem/configuration.py',
#  'dlt/destinations/filesystem/filesystem.py',
#  'dlt/destinations/insert_job_client.py',
#  'dlt/destinations/job_client_impl.py',
#  'dlt/destinations/job_impl.py',
#  'dlt/destinations/motherduck/__init__.py',
#  'dlt/destinations/motherduck/configuration.py',
#  'dlt/destinations/motherduck/motherduck.py',
#  'dlt/destinations/motherduck/sql_client.py',
#  'dlt/destinations/mssql/README.md',
#  'dlt/destinations/mssql/__init__.py',
#  'dlt/destinations/mssql/configuration.py',
#  'dlt/destinations/mssql/mssql.py',
#  'dlt/destinations/mssql/sql_client.py',
#  'dlt/destinations/path_utils.py',
#  'dlt/destinations/postgres/README.md',
#  'dlt/destinations/postgres/__init__.py',
#  'dlt/destinations/postgres/configuration.py',
#  'dlt/destinations/postgres/postgres.py',
#  'dlt/destinations/postgres/sql_client.py',
#  'dlt/destinations/qdrant/__init__.py',
#  'dlt/destinations/qdrant/configuration.py',
#  'dlt/destinations/qdrant/qdrant_adapter.py',
#  'dlt/destinations/qdrant/qdrant_client.py',
#  'dlt/destinations/redshift/README.md',
#  'dlt/destinations/redshift/__init__.py',
#  'dlt/destinations/redshift/configuration.py',
#  'dlt/destinations/redshift/redshift.py',
#  'dlt/destinations/snowflake/__init__.py',
#  'dlt/destinations/snowflake/configuration.py',
#  'dlt/destinations/snowflake/snowflake.py',
#  'dlt/destinations/snowflake/sql_client.py',
#  'dlt/destinations/sql_client.py',
#  'dlt/destinations/sql_jobs.py',
#  'dlt/destinations/type_mapping.py',
#  'dlt/destinations/typing.py',
#  'dlt/destinations/weaviate/README.md',
#  'dlt/destinations/weaviate/__init__.py',
#  'dlt/destinations/weaviate/ci_naming.py',
#  'dlt/destinations/weaviate/configuration.py',
#  'dlt/destinations/weaviate/exceptions.py',
#  'dlt/destinations/weaviate/naming.py',
#  'dlt/destinations/weaviate/weaviate_adapter.py',
#  'dlt/destinations/weaviate/weaviate_client.py',
#  'dlt/extract/__init__.py',
#  'dlt/extract/decorators.py',
#  'dlt/extract/exceptions.py',
#  'dlt/extract/extract.py',
#  'dlt/extract/incremental/__init__.py',
#  'dlt/extract/incremental/exceptions.py',
#  'dlt/extract/incremental/transform.py',
#  'dlt/extract/incremental/typing.py',
#  'dlt/extract/pipe.py',
#  'dlt/extract/schema.py',
#  'dlt/extract/source.py',
#  'dlt/extract/typing.py',
#  'dlt/extract/utils.py',
#  'dlt/extract/validation.py',
#  'dlt/extract/wrappers.py',
#  'dlt/helpers/__init__.py',
#  'dlt/helpers/airflow_helper.py',
#  'dlt/helpers/dbt/__init__.py',
#  'dlt/helpers/dbt/configuration.py',
#  'dlt/helpers/dbt/dbt_utils.py',
#  'dlt/helpers/dbt/exceptions.py',
#  'dlt/helpers/dbt/profiles.yml',
#  'dlt/helpers/dbt/runner.py',
#  'dlt/helpers/dbt_cloud/__init__.py',
#  'dlt/helpers/dbt_cloud/client.py',
#  'dlt/helpers/dbt_cloud/configuration.py',
#  'dlt/helpers/streamlit_helper.py',
#  'dlt/load/__init__.py',
#  'dlt/load/configuration.py',
#  'dlt/load/exceptions.py',
#  'dlt/load/load.py',
#  'dlt/normalize/__init__.py',
#  'dlt/normalize/configuration.py',
#  'dlt/normalize/exceptions.py',
#  'dlt/normalize/items_normalizers.py',
#  'dlt/normalize/normalize.py',
#  'dlt/pipeline/__init__.py',
#  'dlt/pipeline/configuration.py',
#  'dlt/pipeline/current.py',
#  'dlt/pipeline/dbt.py',
#  'dlt/pipeline/exceptions.py',
#  'dlt/pipeline/helpers.py',
#  'dlt/pipeline/mark.py',
#  'dlt/pipeline/pipeline.py',
#  'dlt/pipeline/progress.py',
#  'dlt/pipeline/state_sync.py',
#  'dlt/pipeline/trace.py',
#  'dlt/pipeline/track.py',
#  'dlt/pipeline/typing.py',
#  'dlt/py.typed',
#  'dlt/reflection/__init__.py',
#  'dlt/reflection/names.py',
#  'dlt/reflection/script_inspector.py',
#  'dlt/reflection/script_visitor.py',
#  'dlt/sources/__init__.py',
#  'dlt/sources/config.py',
#  'dlt/sources/credentials.py',
#  'dlt/sources/filesystem.py',
#  'dlt/sources/helpers/__init__.py',
#  'dlt/sources/helpers/requests/__init__.py',
#  'dlt/sources/helpers/requests/retry.py',
#  'dlt/sources/helpers/requests/session.py',
#  'dlt/sources/helpers/requests/typing.py',
#  'dlt/sources/helpers/transform.py',
#  'dlt/version.py',
#  'docs/__init__.py',
#  'docs/examples/CONTRIBUTING.md',
#  'docs/examples/archive/.dlt/example.secrets.toml',
#  'docs/examples/archive/README.md',
#  'docs/examples/archive/__init__.py',
#  'docs/examples/archive/_helpers.py',
#  'docs/examples/archive/credentials/.dlt/config.toml',
#  'docs/examples/archive/credentials/__init__.py',
#  'docs/examples/archive/credentials/explicit.py',
#  'docs/examples/archive/data/channels.json',
#  'docs/examples/archive/data/demo_example.json',
#  'docs/examples/archive/data/messages.json',
#  'docs/examples/archive/data/rasa_trackers/2888158124550630_tracker.jsonl',
#  'docs/examples/archive/data/rasa_trackers/8629c904-0c26-4f0b-927b-14d48db43c28_tracker.jsonl',
#  'docs/examples/archive/data/singer_taps/csv_catalog.json',
#  'docs/examples/archive/data/singer_taps/model_annotations.csv',
#  'docs/examples/archive/data/singer_taps/tap_google_sheet.jsonl',
#  'docs/examples/archive/data/singer_taps/tap_hubspot.jsonl',
#  'docs/examples/archive/dbt_run_jaffle.py',
#  'docs/examples/archive/discord_iterator.py',
#  'docs/examples/archive/examples/schemas/dlt_quickstart.schema.yaml',
#  'docs/examples/archive/google_drive_csv.py',
#  'docs/examples/archive/google_sheets.py',
#  'docs/examples/archive/quickstart.py',
#  'docs/examples/archive/rasa_example.py',
#  'docs/examples/archive/read_table.py',
#  'docs/examples/archive/restore_pipeline.py',
#  'docs/examples/archive/schemas/__init__.py',
#  'docs/examples/archive/schemas/discord.schema.yml',
#  'docs/examples/archive/schemas/dlt_quickstart.schema.yaml',
#  'docs/examples/archive/schemas/hubspot.schema.yaml',
#  'docs/examples/archive/schemas/inferred_demo.schema.yml',
#  'docs/examples/archive/singer_tap_example.py',
#  'docs/examples/archive/singer_tap_jsonl_example.py',
#  'docs/examples/archive/sources/__init__.py',
#  'docs/examples/archive/sources/google_sheets.py',
#  'docs/examples/archive/sources/jsonl.py',
#  'docs/examples/archive/sources/rasa/__init__.py',
#  'docs/examples/archive/sources/rasa/rasa.py',
#  'docs/examples/archive/sources/rasa/rasa.schema.yaml',
#  'docs/examples/archive/sources/singer_tap.py',
#  'docs/examples/archive/sources/sql_query.py',
#  'docs/examples/archive/sources/stdout.py',
#  'docs/examples/archive/sync_schema_example.py',
#  'docs/examples/chess/.dlt/config.toml',
#  'docs/examples/chess/__init__.py',
#  'docs/examples/chess/chess.py',
#  'docs/examples/chess/chess_dbt.py',
#  'docs/examples/chess/dbt_transform/.gitignore',
#  'docs/examples/chess/dbt_transform/analyses/.gitkeep',
#  'docs/examples/chess/dbt_transform/dbt_project.yml',
#  'docs/examples/chess/dbt_transform/macros/.gitkeep',
#  'docs/examples/chess/dbt_transform/models/_dlt_loads.sql',
#  'docs/examples/chess/dbt_transform/models/load_ids.sql',
#  'docs/examples/chess/dbt_transform/models/schema.yml',
#  'docs/examples/chess/dbt_transform/models/sources.yml',
#  'docs/examples/chess/dbt_transform/models/view_player_games.sql',
#  'docs/examples/chess/dbt_transform/packages.yml',
#  'docs/examples/chess/dbt_transform/seeds/.gitkeep',
#  'docs/examples/chess/dbt_transform/snapshots/.gitkeep',
#  'docs/examples/chess/dbt_transform/tests/.gitkeep',
#  'docs/examples/chess_production/.dlt/config.toml',
#  'docs/examples/chess_production/__init__.py',
#  'docs/examples/chess_production/chess.py',
#  'docs/examples/connector_x_arrow/__init__.py',
#  'docs/examples/incremental_loading/.dlt/config.toml',
#  'docs/examples/incremental_loading/.dlt/secrets.toml',
#  'docs/examples/incremental_loading/__init__.py',
#  'docs/examples/incremental_loading/zendesk.py',
#  'docs/examples/nested_data/.dlt/config.toml',
#  'docs/examples/nested_data/.dlt/secrets.toml',
#  'docs/examples/nested_data/__init__.py',
#  'docs/examples/nested_data/nested_data.py',
#  'docs/examples/transformers/.dlt/config.toml',
#  'docs/examples/transformers/__init__.py',
#  'docs/examples/transformers/pokemon.py',
#  'docs/examples/transformers_and_parallelism/__init__.py',
#  'docs/technical/README.md',
#  'docs/technical/create_pipeline.md',
#  'docs/technical/customization_and_hacking.md',
#  'docs/technical/general_usage.md',
#  'docs/technical/working_with_schemas.md',
#  'docs/website/.gitignore',
#  'docs/website/.npmrc',
#  'docs/website/README.md',
#  'docs/website/__init__.py',
#  'docs/website/babel.config.js',
#  'docs/website/blog/2023-02-16-dlthub-mission.md',
#  'docs/website/blog/2023-02-22-dlthub-who-we-serve.md',
#  'docs/website/blog/2023-03-09-duckdb-1M-downloads-users.mdx',
#  'docs/website/blog/2023-03-16-is-duckdb-a-database-for-ducks.mdx',
#  'docs/website/blog/2023-04-27-ga4-internal-dashboard-demo.md',
#  'docs/website/blog/2023-05-15-hacker-news-gpt-4-dashboard-demo.md',
#  'docs/website/blog/2023-05-25-postgresql-bigquery-metabase-demo.md',
#  'docs/website/blog/2023-05-26-structured-data-lakes-through-schema-evolution-next-generation-data-platform.md',
#  'docs/website/blog/2023-06-05-google-sheets-to-data-warehouse-pipeline.md',
#  'docs/website/blog/2023-06-10-schema-evolution.md',
#  'docs/website/blog/2023-06-14-dlthub-gpt-accelerated learning_01.md',
#  'docs/website/blog/2023-06-15-automating-data-engineers.md',
#  'docs/website/blog/2023-06-20-dlthub-gptquestion1-.md',
#  'docs/website/blog/2023-06-21-open-api-spec-for-dlt-init.md',
#  'docs/website/blog/2023-06-26-dlthub-gptquestion2.md',
#  'docs/website/blog/2023-08-14-dlt-motherduck-blog.md',
#  'docs/website/blog/2023-08-21-dlt-lineage-support.md',
#  'docs/website/blog/2023-08-24-dlt-etlt.md',
#  'docs/website/blog/2023-09-05-mongo-etl.md',
#  'docs/website/blog/2023-09-20-data-engineering-cv.md',
#  'docs/website/blog/2023-09-26-verba-dlt-zendesk.md',
#  'docs/website/blog/2023-10-06-dlt-holistics.md',
#  'docs/website/blog/2023-10-09-dlt-ops-startups.md',
#  'docs/website/blog/2023-10-10-data-product-docs.md',
#  'docs/website/blog/2023-10-16-first-data-warehouse.md',
#  'docs/website/blog/2023-10-19-dbt-runners.md',
#  'docs/website/blog/2023-10-23-arrow-loading.md',
#  'docs/website/blog/2023-10-25-dlt-deepnote.md',
#  'docs/website/blog/2023-10-26-dlt-prefect.md',
#  'docs/website/blog/2023-10-30-data-modelling-tools.md',
#  'docs/website/blog/2023-11-01-dlt-dagster.md',
#  'docs/website/blog/2023-11-08-solving-ingestion.md',
#  'docs/website/blog/2023-11-22-dlt-webhooks-event-based-ingestion.md',
#  'docs/website/blog/2023-11-27-dlt-data-lineage.md',
#  'docs/website/blog/2023-11-29-exploring-data-replication-of-sap-hana-to-snowflake-using-dlt.md',
#  'docs/website/blog/2023-12-01-dlt-kestra-demo.md',
#  'docs/website/blog/authors.yml',
#  'docs/website/docs/.dlt/config.toml',
#  'docs/website/docs/__init__.py',
#  'docs/website/docs/assets/invoices/invoice_2.txt',
#  'docs/website/docs/assets/invoices/invoice_20230831-p1.pdf',
#  'docs/website/docs/assets/json_file.json',
#  'docs/website/docs/build-a-pipeline-tutorial.md',
#  'docs/website/docs/conftest.py',
#  'docs/website/docs/dlt-ecosystem/destinations/athena.md',
#  'docs/website/docs/dlt-ecosystem/destinations/bigquery.md',
#  'docs/website/docs/dlt-ecosystem/destinations/duckdb.md',
#  'docs/website/docs/dlt-ecosystem/destinations/filesystem.md',
#  'docs/website/docs/dlt-ecosystem/destinations/index.md',
#  'docs/website/docs/dlt-ecosystem/destinations/motherduck.md',
#  'docs/website/docs/dlt-ecosystem/destinations/mssql.md',
#  'docs/website/docs/dlt-ecosystem/destinations/postgres.md',
#  'docs/website/docs/dlt-ecosystem/destinations/qdrant.md',
#  'docs/website/docs/dlt-ecosystem/destinations/redshift.md',
#  'docs/website/docs/dlt-ecosystem/destinations/snowflake.md',
#  'docs/website/docs/dlt-ecosystem/destinations/weaviate.md',
#  'docs/website/docs/dlt-ecosystem/file-formats/insert-format.md',
#  'docs/website/docs/dlt-ecosystem/file-formats/jsonl.md',
#  'docs/website/docs/dlt-ecosystem/file-formats/parquet.md',
#  'docs/website/docs/dlt-ecosystem/staging.md',
#  'docs/website/docs/dlt-ecosystem/transformations/dbt/__init__.py',
#  'docs/website/docs/dlt-ecosystem/transformations/dbt/dbt-snippets.py',
#  'docs/website/docs/dlt-ecosystem/transformations/dbt/dbt.md',
#  'docs/website/docs/dlt-ecosystem/transformations/dbt/dbt_cloud.md',
#  'docs/website/docs/dlt-ecosystem/transformations/dbt/profiles.yml',
#  'docs/website/docs/dlt-ecosystem/transformations/pandas.md',
#  'docs/website/docs/dlt-ecosystem/transformations/sql.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/airtable.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/amazon_kinesis.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/arrow-pandas.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/asana.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/chess.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/docs_images/Add_people.png',
#  'docs/website/docs/dlt-ecosystem/verified-sources/docs_images/Airtable_ids.jpeg',
#  'docs/website/docs/dlt-ecosystem/verified-sources/docs_images/GA4_Property_ID_size.png',
#  'docs/website/docs/dlt-ecosystem/verified-sources/docs_images/Matomo_name_and_id.png',
#  'docs/website/docs/dlt-ecosystem/verified-sources/docs_images/Notion_Database_2.jpeg',
#  'docs/website/docs/dlt-ecosystem/verified-sources/docs_images/Share_button.png',
#  'docs/website/docs/dlt-ecosystem/verified-sources/docs_images/Zendesk_Admin.jpeg',
#  'docs/website/docs/dlt-ecosystem/verified-sources/docs_images/Zendesk_chat_access_token.jpg',
#  'docs/website/docs/dlt-ecosystem/verified-sources/facebook_ads.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/filesystem.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/github.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/google_analytics.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/google_sheets.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/hubspot.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/inbox.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/index.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/jira.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/matomo.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/mongodb.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/mux.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/notion.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/personio.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/pipedrive.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/salesforce.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/shopify.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/slack.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/sql_database.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/strapi.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/stripe.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/workable.md',
#  'docs/website/docs/dlt-ecosystem/verified-sources/zendesk.md',
#  'docs/website/docs/dlt-ecosystem/visualizations/exploring-the-data.md',
#  'docs/website/docs/examples/_examples-header.md',
#  'docs/website/docs/examples/chess_production/__init__.py',
#  'docs/website/docs/examples/chess_production/code/.dlt/config.toml',
#  'docs/website/docs/examples/chess_production/code/__init__.py',
#  'docs/website/docs/examples/chess_production/code/chess-snippets.py',
#  'docs/website/docs/examples/chess_production/index.md',
#  'docs/website/docs/examples/connector_x_arrow/__init__.py',
#  'docs/website/docs/examples/connector_x_arrow/code/__init__.py',
#  'docs/website/docs/examples/connector_x_arrow/code/load_arrow-snippets.py',
#  'docs/website/docs/examples/connector_x_arrow/index.md',
#  'docs/website/docs/examples/incremental_loading/__init__.py',
#  'docs/website/docs/examples/incremental_loading/code/.dlt/config.toml',
#  'docs/website/docs/examples/incremental_loading/code/.dlt/secrets.toml',
#  'docs/website/docs/examples/incremental_loading/code/__init__.py',
#  'docs/website/docs/examples/incremental_loading/code/zendesk-snippets.py',
#  'docs/website/docs/examples/incremental_loading/index.md',
#  'docs/website/docs/examples/index.md',
#  'docs/website/docs/examples/nested_data/__init__.py',
#  'docs/website/docs/examples/nested_data/code/.dlt/config.toml',
#  'docs/website/docs/examples/nested_data/code/.dlt/secrets.toml',
#  'docs/website/docs/examples/nested_data/code/__init__.py',
#  'docs/website/docs/examples/nested_data/code/nested_data-snippets.py',
#  'docs/website/docs/examples/nested_data/index.md',
#  'docs/website/docs/examples/transformers/__init__.py',
#  'docs/website/docs/examples/transformers/code/.dlt/config.toml',
#  'docs/website/docs/examples/transformers/code/__init__.py',
#  'docs/website/docs/examples/transformers/code/pokemon-snippets.py',
#  'docs/website/docs/examples/transformers/index.md',
#  'docs/website/docs/general-usage/credentials/config_providers.md',
#  'docs/website/docs/general-usage/credentials/config_specs.md',
#  'docs/website/docs/general-usage/credentials/configuration.md',
#  'docs/website/docs/general-usage/customising-pipelines/pseudonymizing_columns.md',
#  'docs/website/docs/general-usage/customising-pipelines/renaming_columns.md',
#  'docs/website/docs/general-usage/destination-tables.md',
#  'docs/website/docs/general-usage/full-loading.md',
#  'docs/website/docs/general-usage/glossary.md',
#  'docs/website/docs/general-usage/incremental-loading.md',
#  'docs/website/docs/general-usage/pipeline.md',
#  'docs/website/docs/general-usage/resource.md',
#  'docs/website/docs/general-usage/schema.md',
#  'docs/website/docs/general-usage/source.md',
#  'docs/website/docs/general-usage/state.md',
#  'docs/website/docs/getting-started-snippets.py',
#  'docs/website/docs/getting-started.md',
#  'docs/website/docs/intro-snippets.py',
#  'docs/website/docs/intro.md',
#  'docs/website/docs/reference/__init__.py',
#  'docs/website/docs/reference/command-line-interface.md',
#  'docs/website/docs/reference/explainers/airflow-gcp-cloud-composer.md',
#  'docs/website/docs/reference/explainers/how-dlt-works.md',
#  'docs/website/docs/reference/installation.md',
#  'docs/website/docs/reference/performance.md',
#  'docs/website/docs/reference/performance_snippets/.dlt/config.toml',
#  'docs/website/docs/reference/performance_snippets/__init__.py',
#  'docs/website/docs/reference/performance_snippets/performance-snippets.py',
#  'docs/website/docs/reference/performance_snippets/toml-snippets.toml',
#  'docs/website/docs/reference/telemetry.md',
#  'docs/website/docs/running-in-production/alerting.md',
#  'docs/website/docs/running-in-production/images/airflow_dag_tasks.png',
#  'docs/website/docs/running-in-production/images/airflow_dags.png',
#  'docs/website/docs/running-in-production/images/airflow_slack_notification.png',
#  'docs/website/docs/running-in-production/images/github_actions_workflow_dag.png',
#  'docs/website/docs/running-in-production/images/github_actions_workflows.png',
#  'docs/website/docs/running-in-production/monitoring.md',
#  'docs/website/docs/running-in-production/running.md',
#  'docs/website/docs/running-in-production/tracing.md',
#  'docs/website/docs/utils.py',
#  'docs/website/docs/walkthroughs/add-a-verified-source.md',
#  'docs/website/docs/walkthroughs/add_credentials.md',
#  'docs/website/docs/walkthroughs/adjust-a-schema.md',
#  'docs/website/docs/walkthroughs/create-a-pipeline.md',
#  'docs/website/docs/walkthroughs/create-new-destination.md',
#  'docs/website/docs/walkthroughs/deploy-a-pipeline/deploy-gcp-cloud-function-as-webhook.md',
#  'docs/website/docs/walkthroughs/deploy-a-pipeline/deploy-with-airflow-composer.md',
#  'docs/website/docs/walkthroughs/deploy-a-pipeline/deploy-with-github-actions.md',
#  'docs/website/docs/walkthroughs/deploy-a-pipeline/deploy-with-google-cloud-functions.md',
#  'docs/website/docs/walkthroughs/deploy-a-pipeline/images/add-credential.png',
#  'docs/website/docs/walkthroughs/deploy-a-pipeline/images/dag-folder.png',
#  'docs/website/docs/walkthroughs/deploy-a-pipeline/images/run-trigger.png',
#  'docs/website/docs/walkthroughs/run-a-pipeline.md',
#  'docs/website/docs/walkthroughs/share-a-dataset.md',
#  'docs/website/docs/walkthroughs/zendesk-weaviate.md',
#  'docs/website/docusaurus.config.js',
#  'docs/website/netlify.toml',
#  'docs/website/package-lock.json',
#  'docs/website/package.json',
#  'docs/website/pydoc-markdown.yml',
#  'docs/website/pydoc_markdown_dlt.py',
#  'docs/website/requirements.txt',
#  'docs/website/sidebars.js',
#  'docs/website/src/css/custom.css',
#  'docs/website/src/theme/DLTExampleHeader.tsx',
#  'docs/website/src/theme/MDXComponents.js',
#  'docs/website/src/theme/Root.js',
#  'docs/website/static/.nojekyll',
#  'docs/website/static/img/CO-Blue.svg',
#  'docs/website/static/img/CO-White.svg',
#  'docs/website/static/img/Concepts - Active.svg',
#  'docs/website/static/img/Concepts - Inactive.svg',
#  'docs/website/static/img/Customization-Active-1.svg',
#  'docs/website/static/img/Customization-Active.svg',
#  'docs/website/static/img/Customization-Inactive-1.svg',
#  'docs/website/static/img/Customization-Inactive.svg',
#  'docs/website/static/img/Destinations-Active-1.svg',
#  'docs/website/static/img/Destinations-Active.svg',
#  'docs/website/static/img/Destinations-Inactive-1.svg',
#  'docs/website/static/img/Destinations-Inactive.svg',
#  'docs/website/static/img/GeneralUsage-Active-1.svg',
#  'docs/website/static/img/GeneralUsage-Active.svg',
#  'docs/website/static/img/GeneralUsage-Inactive-1.svg',
#  'docs/website/static/img/GeneralUsage-Inactive.svg',
#  'docs/website/static/img/GettingStarted-Active-1.svg',
#  'docs/website/static/img/GettingStarted-Active.svg',
#  'docs/website/static/img/GettingStarted-Inactive-1.svg',
#  'docs/website/static/img/GettingStarted-Inactive.svg',
#  'docs/website/static/img/GithubDark.svg',
#  'docs/website/static/img/GithubLight.svg',
#  'docs/website/static/img/Holistics_new.gif',
#  'docs/website/static/img/Howdltworks-Active-1.svg',
#  'docs/website/static/img/Howdltworks-Active.svg',
#  'docs/website/static/img/Howdltworks-Inactive-1.svg',
#  'docs/website/static/img/Howdltworks-Inactive.svg',
#  'docs/website/static/img/Installation-Active-1.svg',
#  'docs/website/static/img/Installation-Active.svg',
#  'docs/website/static/img/Installation-Inactive-1.svg',
#  'docs/website/static/img/Installation-Inactive.svg',
#  'docs/website/static/img/Introduction-Active-1.svg',
#  'docs/website/static/img/Introduction-Active.svg',
#  'docs/website/static/img/Introduction-Inactive-1.svg',
#  'docs/website/static/img/Introduction-Inactive.svg',
#  'docs/website/static/img/Marcin-dltHub-DuckDB-DuckCon-Brussels.jpg',
#  'docs/website/static/img/Pipelines-Active-1.svg',
#  'docs/website/static/img/Pipelines-Active.svg',
#  'docs/website/static/img/Pipelines-Inactive-1.svg',
#  'docs/website/static/img/Pipelines-Inactive.svg',
#  'docs/website/static/img/Reference-Active-1.svg',
#  'docs/website/static/img/Reference-Active.svg',
#  'docs/website/static/img/Reference-Inactive-1.svg',
#  'docs/website/static/img/Reference-Inactive.svg',
#  'docs/website/static/img/RunningInProduction-Active-1.svg',
#  'docs/website/static/img/RunningInProduction-Active.svg',
#  'docs/website/static/img/RunningInProduction-Inactive-1.svg',
#  'docs/website/static/img/RunningInProduction-Inactive.svg',
#  'docs/website/static/img/SlackDark.svg',
#  'docs/website/static/img/SlackLight.svg',
#  'docs/website/static/img/UserGuide-Active-1.svg',
#  'docs/website/static/img/UserGuide-Active.svg',
#  'docs/website/static/img/UserGuide-Inactive-1.svg',
#  'docs/website/static/img/UserGuide-Inactive.svg',
#  'docs/website/static/img/UsingLoadedData-Active-1.svg',
#  'docs/website/static/img/UsingLoadedData-Active.svg',
#  'docs/website/static/img/UsingLoadedData-Inactive-1.svg',
#  'docs/website/static/img/UsingLoadedData-Inactive.svg',
#  'docs/website/static/img/Walkthrough-Active-1.svg',
#  'docs/website/static/img/Walkthrough-Active.svg',
#  'docs/website/static/img/Walkthrough-Inactive-1.svg',
#  'docs/website/static/img/Walkthrough-Inactive.svg',
#  'docs/website/static/img/add-credential.png',
#  'docs/website/static/img/add-package.png',
#  'docs/website/static/img/architecture-diagram.png',
#  'docs/website/static/img/arrow_30x_faster.png',
#  'docs/website/static/img/blog-ingestion-etl-tools-users.png',
#  'docs/website/static/img/blog-modelling-data-dictionaries-gooddata.png',
#  'docs/website/static/img/blog-modelling-data-dictionaries-metabase.png',
#  'docs/website/static/img/blog-modelling-data-dictionaries-pbi.png',
#  'docs/website/static/img/blog-modelling-data-types-power-bi.png',
#  'docs/website/static/img/blog-modelling-granularity-gooddata.png',
#  'docs/website/static/img/blog-modelling-granularity-metabase.png',
#  'docs/website/static/img/blog-modelling-granularity-pbi.png',
#  'docs/website/static/img/blog-modelling-language-gooddata.png',
#  'docs/website/static/img/blog-modelling-language-metabase.png',
#  'docs/website/static/img/blog-modelling-language-pbi.png',
#  'docs/website/static/img/blog-modelling-metrics-gooddata.png',
#  'docs/website/static/img/blog-modelling-metrics-metabase.png',
#  'docs/website/static/img/blog-modelling-metrics-pbi.png',
#  'docs/website/static/img/blog-modelling-refresh-gooddata.png',
#  'docs/website/static/img/blog-modelling-refresh-metabase.png',
#  'docs/website/static/img/blog-modelling-refresh-pbi.png',
#  'docs/website/static/img/blog-modelling-table-prop-gooddata.png',
#  'docs/website/static/img/blog-modelling-table-prop-metabase.png',
#  'docs/website/static/img/blog-modelling-table-prop-pbi.png',
#  'docs/website/static/img/blog-modelling-table-rel-gooddata.png',
#  'docs/website/static/img/blog-modelling-table-rel-metabase.png',
#  'docs/website/static/img/blog-modelling-table-rel-pbi.png',
#  'docs/website/static/img/blog-what_would_drake_do.png',
#  'docs/website/static/img/blog_deepnote_animation.gif',
#  'docs/website/static/img/blog_deepnote_chart.png',
#  'docs/website/static/img/blog_deepnote_improved_flow.png',
#  'docs/website/static/img/blog_deepnote_usual_flow.png',
#  'docs/website/static/img/blog_gpt_1.jpg',
#  'docs/website/static/img/blog_gpt_QA2.jpg',
#  'docs/website/static/img/bucket-details.png',
#  'docs/website/static/img/chatgptQ1.png',
#  'docs/website/static/img/chatgptQ2..png',
#  'docs/website/static/img/dall-e-de-cv.png',
#  'docs/website/static/img/data-dumpster.png',
#  'docs/website/static/img/data-types-gooddata.png',
#  'docs/website/static/img/data-types-metabase.png',
#  'docs/website/static/img/dlt-business-knowledge-retrieval-augmented-generation-diagram.png',
#  'docs/website/static/img/dlt-high-level.png',
#  'docs/website/static/img/dlt-logo-old.svg',
#  'docs/website/static/img/dlt-logo.svg',
#  'docs/website/static/img/dlt-motherduck-dashboard-1.png',
#  'docs/website/static/img/dlt-motherduck-dashboard-2.png',
#  'docs/website/static/img/dlt-motherduck-dashboard-3.png',
#  'docs/website/static/img/dlt-motherduck-dashboard-4.png',
#  'docs/website/static/img/dlt-motherduck-duckdb-explore.png',
#  'docs/website/static/img/dlt-motherduck-local-workflow.png',
#  'docs/website/static/img/dlt-motherduck-logos.png',
#  'docs/website/static/img/dlt-motherduck-nested-bigquery.png',
#  'docs/website/static/img/dlt-motherduck-normalized-bigquery.png',
#  'docs/website/static/img/dlt-motherduck-production-workflow.png',
#  'docs/website/static/img/dlt-motherduck-share.png',
#  'docs/website/static/img/dlt-pacman.gif',
#  'docs/website/static/img/dlt-weaviate-verba-ui-1.png',
#  'docs/website/static/img/dlt-weaviate-verba-ui-2.png',
#  'docs/website/static/img/dlt.png',
#  'docs/website/static/img/dlt_holistics_bigquery_data.png',
#  'docs/website/static/img/dlt_holistics_bigquery_table.png',
#  'docs/website/static/img/dlt_holistics_overview.jpg',
#  'docs/website/static/img/dlthelp.jpg',
#  'docs/website/static/img/dlthub-logo.png',
#  'docs/website/static/img/docs_where_does_dlt_fit_in_ETL_pipeline.png',
#  'docs/website/static/img/docusaurus.png',
#  'docs/website/static/img/experiment3_dashboard_orders_chart.png',
#  'docs/website/static/img/experiment3_dashboard_top_selling_tables.png',
#  'docs/website/static/img/experiment3_low_stock_email_alert.png',
#  'docs/website/static/img/experiment3_low_stock_file_csv.png',
#  'docs/website/static/img/experiment4-blog-image.png',
#  'docs/website/static/img/experiment4-campaign-roi-dashboard-1.png',
#  'docs/website/static/img/experiment4-campaign-roi-dashboard-2.png',
#  'docs/website/static/img/experiment4-campaign-roi-datawarehouse.png',
#  'docs/website/static/img/experiment4-campaign-roi-google-sheets.png',
#  'docs/website/static/img/experiment4-customer-support-platform-dashboard.png',
#  'docs/website/static/img/experiment4-customer-support-platform-data-warehouse.png',
#  'docs/website/static/img/experiment4-customer-support-platform-google-sheets.png',
#  'docs/website/static/img/eye_of_data_lineage.png',
#  'docs/website/static/img/favicon.ico',
#  'docs/website/static/img/g4_dashboard_screen_grab_1.jpg',
#  'docs/website/static/img/g4_dashboard_screen_grab_2.jpg',
#  'docs/website/static/img/hn_gpt_dashboard.png',
#  'docs/website/static/img/holistics_add_dataset.png',
#  'docs/website/static/img/holistics_add_model.png',
#  'docs/website/static/img/holistics_add_relationship.png',
#  'docs/website/static/img/holistics_dashboard.png',
#  'docs/website/static/img/holistics_overview.png',
#  'docs/website/static/img/holistics_relationship_gui.png',
#  'docs/website/static/img/invoice_flowchart.png',
#  'docs/website/static/img/loading.svg',
#  'docs/website/static/img/logo.svg',
#  'docs/website/static/img/oil-painted-dashboard.png',
#  'docs/website/static/img/open-core-data-stack.png',
#  'docs/website/static/img/open-source.svg',
#  'docs/website/static/img/parrot-baby.gif',
#  'docs/website/static/img/pbi-modelled-livewell.png',
#  'docs/website/static/img/pdf_parse_outcome_1.png',
#  'docs/website/static/img/pdf_parse_outcome_2.png',
#  'docs/website/static/img/pdf_parse_outcome_3.png',
#  'docs/website/static/img/people-stuck-with-tables-2.jpg',
#  'docs/website/static/img/pipeline-automaton.png',
#  'docs/website/static/img/pipeline.png',
#  'docs/website/static/img/prefect-dlt.png',
#  'docs/website/static/img/purple-python-spoderweb.png',
#  'docs/website/static/img/python.svg',
#  'docs/website/static/img/schema_evolution_colab_demo.png',
#  'docs/website/static/img/schema_evolution_colab_demo_light.png',
#  'docs/website/static/img/streamlit1.png',
#  'docs/website/static/img/structured_lake.png',
#  'docs/website/static/img/test-composer.png',
#  'docs/website/static/img/traingptblog.jpg',
#  'docs/website/static/img/trigger-config.png',
#  'docs/website/static/img/undraw_docusaurus_mountain.svg',
#  'docs/website/static/img/undraw_docusaurus_react.svg',
#  'docs/website/static/img/undraw_docusaurus_tree.svg',
#  'docs/website/static/img/went-full-etltlt.png',
#  'docs/website/static/img/why-duckdb.png',
#  'docs/website/static/img/write-dispo-choice.png',
#  'docs/website/tools/update_snippets.js',
#  'docs/website/tools/update_version_env.js',
#  'mypy.ini',
#  'poetry-deps.sh',
#  'poetry.lock',
#  'pyproject.toml',
#  'pytest.ini',
#  'tests/.dlt/config.toml',
#  'tests/.example.env',
#  'tests/__init__.py',
#  'tests/cases.py',
#  'tests/cli/__init__.py',
#  'tests/cli/cases/deploy_pipeline/.dlt/config.toml',
#  'tests/cli/cases/deploy_pipeline/.dlt/secrets.toml',
#  'tests/cli/cases/deploy_pipeline/.dlt/secrets.toml.ci',
#  'tests/cli/cases/deploy_pipeline/.gitignore',
#  'tests/cli/cases/deploy_pipeline/README.md',
#  'tests/cli/cases/deploy_pipeline/__init__.py',
#  'tests/cli/cases/deploy_pipeline/debug_pipeline.py',
#  'tests/cli/cases/deploy_pipeline/dummy_pipeline.py',
#  'tests/cli/cases/deploy_pipeline/requirements.txt',
#  'tests/cli/common/__init__.py',
#  'tests/cli/common/test_cli_invoke.py',
#  'tests/cli/common/test_telemetry_command.py',
#  'tests/cli/conftest.py',
#  'tests/cli/test_config_toml_writer.py',
#  'tests/cli/test_deploy_command.py',
#  'tests/cli/test_init_command.py',
#  'tests/cli/test_pipeline_command.py',
#  'tests/cli/utils.py',
#  'tests/common/__init__.py',
#  'tests/common/cases/configuration/.dlt/config.toml',
#  'tests/common/cases/configuration/.dlt/secrets.toml',
#  'tests/common/cases/configuration/.wrong.dlt/config.toml',
#  'tests/common/cases/configuration/dlt_home/config.toml',
#  'tests/common/cases/level-dragon-333019-707809ee408a.json.b64',
#  'tests/common/cases/mod_bot_case.json',
#  'tests/common/cases/modules/__init__.py',
#  'tests/common/cases/modules/uniq_mod_121.py',
#  'tests/common/cases/oauth_client_secret_929384042504.json',
#  'tests/common/cases/pua_encoded_row.json',
#  'tests/common/cases/rasa_event_bot_metadata.json',
#  'tests/common/cases/schemas/eth/ethereum_schema_v3.yml',
#  'tests/common/cases/schemas/eth/ethereum_schema_v4.yml',
#  'tests/common/cases/schemas/eth/ethereum_schema_v5.yml',
#  'tests/common/cases/schemas/eth/ethereum_schema_v6.yml',
#  'tests/common/cases/schemas/ev1/event.schema.7z',
#  'tests/common/cases/schemas/ev1/event.schema.bak.json.gz',
#  'tests/common/cases/schemas/ev1/event.schema.json',
#  'tests/common/cases/schemas/ev1/model.schema.json',
#  'tests/common/cases/schemas/ev2/event.schema.json',
#  'tests/common/cases/schemas/github/issues.schema.json',
#  'tests/common/cases/schemas/local/event.schema.json',
#  'tests/common/cases/schemas/local/event.schema.yaml',
#  'tests/common/cases/schemas/local/name_mismatch.schema.yaml',
#  'tests/common/cases/schemas/rasa/event.schema.json',
#  'tests/common/cases/schemas/rasa/model.schema.json',
#  'tests/common/cases/schemas/sheets/google_spreadsheet_v4.schema.json',
#  'tests/common/cases/secret-kube/secret-kube',
#  'tests/common/cases/secret-value',
#  'tests/common/cases/secrets/deploy-key',
#  'tests/common/cases/secrets/deploy_key.pub',
#  'tests/common/cases/secrets/encrypted-private-key',
#  'tests/common/cases/secrets/encrypted-private-key-base64',
#  'tests/common/cases/simple_row.json',
#  'tests/common/cases/weird_rows.json',
#  'tests/common/configuration/__init__.py',
#  'tests/common/configuration/test_accessors.py',
#  'tests/common/configuration/test_configuration.py',
#  'tests/common/configuration/test_container.py',
#  'tests/common/configuration/test_credentials.py',
#  'tests/common/configuration/test_environ_provider.py',
#  'tests/common/configuration/test_inject.py',
#  'tests/common/configuration/test_providers.py',
#  'tests/common/configuration/test_sections.py',
#  'tests/common/configuration/test_spec_union.py',
#  'tests/common/configuration/test_toml_provider.py',
#  'tests/common/configuration/utils.py',
#  'tests/common/data_writers/__init__.py',
#  'tests/common/data_writers/test_buffered_writer.py',
#  'tests/common/data_writers/test_data_writers.py',
#  'tests/common/data_writers/test_parquet_writer.py',
#  'tests/common/normalizers/__init__.py',
#  'tests/common/normalizers/custom_normalizers.py',
#  'tests/common/normalizers/test_import_normalizers.py',
#  'tests/common/normalizers/test_json_relational.py',
#  'tests/common/normalizers/test_naming.py',
#  'tests/common/normalizers/test_naming_duck_case.py',
#  'tests/common/normalizers/test_naming_snake_case.py',
#  'tests/common/reflection/__init__.py',
#  'tests/common/reflection/test_reflect_spec.py',
#  'tests/common/runners/__init__.py',
#  'tests/common/runners/test_pipes.py',
#  'tests/common/runners/test_runnable.py',
#  'tests/common/runners/test_runners.py',
#  'tests/common/runners/test_venv.py',
#  'tests/common/runners/utils.py',
#  'tests/common/runtime/__init__.py',
#  'tests/common/runtime/test_collector.py',
#  'tests/common/runtime/test_logging.py',
#  'tests/common/runtime/test_signals.py',
#  'tests/common/runtime/test_telemetry.py',
#  'tests/common/runtime/utils.py',
#  'tests/common/schema/__init__.py',
#  'tests/common/schema/test_coercion.py',
#  'tests/common/schema/test_detections.py',
#  'tests/common/schema/test_filtering.py',
#  'tests/common/schema/test_inference.py',
#  'tests/common/schema/test_merges.py',
#  'tests/common/schema/test_schema.py',
#  'tests/common/schema/test_versioning.py',
#  'tests/common/scripts/__init__.py',
#  'tests/common/scripts/args.py',
#  'tests/common/scripts/counter.py',
#  'tests/common/scripts/cwd.py',
#  'tests/common/scripts/empty.py',
#  'tests/common/scripts/environ.py',
#  'tests/common/scripts/long_lines.py',
#  'tests/common/scripts/long_lines_fails.py',
#  'tests/common/scripts/no_stdout_exception.py',
#  'tests/common/scripts/no_stdout_no_stderr_with_fail.py',
#  'tests/common/scripts/raises.py',
#  'tests/common/scripts/raising_counter.py',
#  'tests/common/scripts/stdout_encode_exception.py',
#  'tests/common/scripts/stdout_encode_result.py',
#  'tests/common/scripts/stdout_encode_unpicklable.py',
#  'tests/common/storages/__init__.py',
#  'tests/common/storages/samples/csv/freshman_kgs.csv',
#  'tests/common/storages/samples/csv/freshman_lbs.csv',
#  'tests/common/storages/samples/csv/mlb_players.csv',
#  'tests/common/storages/samples/csv/mlb_teams_2012.csv',
#  'tests/common/storages/samples/jsonl/mlb_players.jsonl',
#  'tests/common/storages/samples/met_csv/A801/A881_20230920.csv',
#  'tests/common/storages/samples/met_csv/A803/A803_20230919.csv',
#  'tests/common/storages/samples/met_csv/A803/A803_20230920.csv',
#  'tests/common/storages/samples/parquet/mlb_players.parquet',
#  'tests/common/storages/samples/sample.txt',
#  'tests/common/storages/test_file_storage.py',
#  'tests/common/storages/test_loader_storage.py',
#  'tests/common/storages/test_local_filesystem.py',
#  'tests/common/storages/test_normalize_storage.py',
#  'tests/common/storages/test_schema_storage.py',
#  'tests/common/storages/test_transactional_file.py',
#  'tests/common/storages/test_versioned_storage.py',
#  'tests/common/storages/utils.py',
#  'tests/common/test_arithmetics.py',
#  'tests/common/test_destination.py',
#  'tests/common/test_git.py',
#  'tests/common/test_json.py',
#  'tests/common/test_pipeline_state.py',
#  'tests/common/test_pyarrow.py',
#  'tests/common/test_pydantic.py',
#  'tests/common/test_time.py',
#  'tests/common/test_typing.py',
#  'tests/common/test_utils.py',
#  'tests/common/test_validation.py',
#  'tests/common/test_version.py',
#  'tests/common/test_wei.py',
#  'tests/common/utils.py',
#  'tests/conftest.py',
#  'tests/destinations/__init__.py',
#  'tests/destinations/test_path_utils.py',
#  'tests/extract/__init__.py',
#  'tests/extract/cases/__init__.py',
#  'tests/extract/cases/eth_source/__init__.py',
#  'tests/extract/cases/eth_source/ethereum.schema.yaml',
#  'tests/extract/cases/eth_source/source.py',
#  'tests/extract/cases/section_source/__init__.py',
#  'tests/extract/cases/section_source/external_resources.py',
#  'tests/extract/cases/section_source/named_module.py',
#  'tests/extract/conftest.py',
#  'tests/extract/test_decorators.py',
#  'tests/extract/test_extract.py',
#  'tests/extract/test_extract_pipe.py',
#  'tests/extract/test_incremental.py',
#  'tests/extract/test_sources.py',
#  'tests/extract/test_utils.py',
#  'tests/extract/test_validation.py',
#  'tests/extract/utils.py',
#  'tests/helpers/airflow_tests/__init__.py',
#  'tests/helpers/airflow_tests/conftest.py',
#  'tests/helpers/airflow_tests/test_airflow_provider.py',
#  'tests/helpers/airflow_tests/test_airflow_wrapper.py',
#  'tests/helpers/airflow_tests/test_join_airflow_scheduler.py',
#  'tests/helpers/airflow_tests/utils.py',
#  'tests/helpers/dbt_cloud_tests/__init__.py',
#  'tests/helpers/dbt_cloud_tests/test_dbt_cloud.py',
#  'tests/helpers/dbt_tests/__init__.py',
#  'tests/helpers/dbt_tests/cases/jaffle_customers_incremental.sql',
#  'tests/helpers/dbt_tests/cases/jaffle_customers_incremental_new_column.sql',
#  'tests/helpers/dbt_tests/cases/jaffle_customers_with_error.sql',
#  'tests/helpers/dbt_tests/cases/profiles.yml',
#  'tests/helpers/dbt_tests/cases/profiles_invalid_credentials.yml',
#  'tests/helpers/dbt_tests/cases/run_execution_incremental_fail.pickle.hex',
#  'tests/helpers/dbt_tests/cases/run_result_incremental_fail.pickle.hex',
#  'tests/helpers/dbt_tests/local/__init__.py',
#  'tests/helpers/dbt_tests/local/test_dbt_utils.py',
#  'tests/helpers/dbt_tests/local/test_runner_destinations.py',
#  'tests/helpers/dbt_tests/local/utils.py',
#  'tests/helpers/dbt_tests/test_runner_dbt_versions.py',
#  'tests/helpers/dbt_tests/utils.py',
#  'tests/helpers/providers/__init__.py',
#  'tests/helpers/providers/test_google_secrets_provider.py',
#  'tests/helpers/streamlit_tests/__init__.py',
#  'tests/helpers/streamlit_tests/test_streamlit_show_resources.py',
#  'tests/load/__init__.py',
#  'tests/load/athena_iceberg/__init__.py',
#  'tests/load/athena_iceberg/test_athena_iceberg.py',
#  'tests/load/bigquery/__init__.py',
#  'tests/load/bigquery/test_bigquery_client.py',
#  'tests/load/bigquery/test_bigquery_table_builder.py',
#  'tests/load/cases/__init__.py',
#  'tests/load/cases/event.schema.json',
#  'tests/load/cases/event_user.json',
#  'tests/load/cases/fake_destination.py',
#  'tests/load/cases/loading/event_bot.181291798a78198.0.unsupported_format',
#  'tests/load/cases/loading/event_bot.b1d32c6660b242aaabbf3fc27245b7e6.0.insert_values',
#  'tests/load/cases/loading/event_loop_interrupted.839c6e6b514e427687586ccc65bf133f.0.jsonl',
#  'tests/load/cases/loading/event_user.839c6e6b514e427687586ccc65bf133f.0.jsonl',
#  'tests/load/cases/loading/event_user.b1d32c6660b242aaabbf3fc27245b7e6.0.insert_values',
#  'tests/load/cases/loading/schema.json',
#  'tests/load/cases/loading/schema_updates.json',
#  'tests/load/cases/long_column_name.json',
#  'tests/load/cases/long_table_name.json',
#  'tests/load/conftest.py',
#  'tests/load/duckdb/__init__.py',
#  'tests/load/duckdb/test_duckdb_client.py',
#  'tests/load/duckdb/test_duckdb_table_builder.py',
#  'tests/load/duckdb/test_motherduck_client.py',
#  'tests/load/filesystem/__init__.py',
#  'tests/load/filesystem/test_aws_credentials.py',
#  'tests/load/filesystem/test_azure_credentials.py',
#  'tests/load/filesystem/test_filesystem_client.py',
#  'tests/load/filesystem/test_filesystem_common.py',
#  'tests/load/filesystem/utils.py',
#  'tests/load/mssql/__init__.py',
#  'tests/load/mssql/test_mssql_credentials.py',
#  'tests/load/mssql/test_mssql_table_builder.py',
#  'tests/load/pipeline/__init__.py',
#  'tests/load/pipeline/conftest.py',
#  'tests/load/pipeline/test_arrow_loading.py',
#  ...]

# %% [markdown]
# Multiple files:

# %%
files = fsspec.open_files("gitpythonfs:///tmp/repo_fixture:abranch@**/file*")
len(files)
# Out:
# 4

# %% [markdown]
# # git
#
# existing implementation called [git](https://github.com/fsspec/filesystem_spec/blob/master/fsspec/implementations/git.py)

# %%
fs_git = fsspec.filesystem("git", path="/tmp/repo_fixture")
# "git:///tmp/test_repo:head@inner"

# %%
fs_git.ls("")
# Out:
# [{'type': 'file',
#   'name': 'file1',
#   'hex': 'a906852f929f123eedf16e685caafcf5179a572c',
#   'mode': '100644',
#   'size': 6},
#  {'type': 'file',
#   'name': 'file2',
#   'hex': 'aff88cec66c6b9b9629ad0a288500b36c7e8479a',
#   'mode': '100644',
#   'size': 7}]

# %% [markdown]
# More complex url does not work for instantiation

# %%
fs_git_at_branch = fsspec.filesystem("git:///tmp/repo_fixture:abranch@inner/file3")
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[26], line 1
#
# ----> 1 fs_git_at_branch = fsspec.filesystem("git:///tmp/repo_fixture:abranch@inner/file3")
#
#
#
# File ~/.cache/pypoetry/virtualenvs/dlt-verified-sources-U7wDHhBf-py3.10/lib/python3.10/site-packages/fsspec/registry.py:292, in filesystem(protocol, **storage_options)
#
#     285 if protocol == "arrow_hdfs":
#
#     286     warnings.warn(
#
#     287         "The 'arrow_hdfs' protocol has been deprecated and will be "
#
#     288         "removed in the future. Specify it as 'hdfs'.",
#
#     289         DeprecationWarning,
#
#     290     )
#
# --> 292 cls = get_filesystem_class(protocol)
#
#     293 return cls(**storage_options)
#
#
#
# File ~/.cache/pypoetry/virtualenvs/dlt-verified-sources-U7wDHhBf-py3.10/lib/python3.10/site-packages/fsspec/registry.py:235, in get_filesystem_class(protocol)
#
#     233 if protocol not in registry:
#
#     234     if protocol not in known_implementations:
#
# --> 235         raise ValueError("Protocol not known: %s" % protocol)
#
#     236     bit = known_implementations[protocol]
#
#     237     try:
#
#
#
# ValueError: Protocol not known: git:///tmp/repo_fixture:abranch@inner/file3

# %% [markdown]
# But it does work for "direct" methods like `open()`:

# %%
with fsspec.open("git:///tmp/repo_fixture:file1") as f:
    bytes = f.read()
    assert bytes == b"data00"

bytes
# Out:
# b'data00'

# %% [markdown]
# which also support git refs:

# %%
with fsspec.open("git:///tmp/repo_fixture:master@file1") as f:
    bytes = f.read()
    assert bytes == b"data00"

bytes
# Out:
# b'data00'

# %%
with fsspec.open("git:///tmp/repo_fixture:thetag@file1") as f:
    bytes = f.read()
    assert bytes == b"data00"

bytes
# Out:
# b'data00'

# %%
with fsspec.open("git:///tmp/repo_fixture:abranch@inner/file3") as f:
    bytes = f.read()
    assert bytes == b"data3"

bytes
# Out:
# b'data3'

# %% [markdown]
# With the first commit.
#
# Note: Will be different sha every time repo_fixture is recreated.

# %%
with fsspec.open("git:///tmp/repo_fixture:9bfaaaf97aab0493e0d369cae65580d3c6d95060@file1") as f:
    bytes = f.read()
    assert bytes == b"data0"

bytes
# Out:
# b'data0'

# %%
with fsspec.open("git:///tmp/repo_fixture:abranch@inner/file3") as f:
    bytes = f.read()
    assert bytes == b"data3"

bytes
# Out:
# b'data3'

# %% [markdown]
# Opening multiple files:

# %%
files = fsspec.open_files("git:///tmp/repo_fixture:abranch@**/file*")
files
# Out:
# <List of 4 OpenFile instances>

# %% [markdown]
# # file (local)
#
# Note these will return the .git folder and contents, which file:// protocol just sees as regular folders and files.

# %%
fs_file = fsspec.filesystem("file")
fs_file.ls("/tmp/repo_fixture")
# Out:
# ['/tmp/repo_fixture/file2',
#  '/tmp/repo_fixture/.git',
#  '/tmp/repo_fixture/inner',
#  '/tmp/repo_fixture/file1']

# %% [markdown]
# find() gives list of files. It recruses subfolders

# %%
fs_file.find("/tmp/repo_fixture")
# Out:
# ['/tmp/repo_fixture/.git/COMMIT_EDITMSG',
#  '/tmp/repo_fixture/.git/HEAD',
#  '/tmp/repo_fixture/.git/config',
#  '/tmp/repo_fixture/.git/description',
#  '/tmp/repo_fixture/.git/hooks/applypatch-msg.sample',
#  '/tmp/repo_fixture/.git/hooks/commit-msg.sample',
#  '/tmp/repo_fixture/.git/hooks/fsmonitor-watchman.sample',
#  '/tmp/repo_fixture/.git/hooks/post-update.sample',
#  '/tmp/repo_fixture/.git/hooks/pre-applypatch.sample',
#  '/tmp/repo_fixture/.git/hooks/pre-commit.sample',
#  '/tmp/repo_fixture/.git/hooks/pre-merge-commit.sample',
#  '/tmp/repo_fixture/.git/hooks/pre-push.sample',
#  '/tmp/repo_fixture/.git/hooks/pre-rebase.sample',
#  '/tmp/repo_fixture/.git/hooks/pre-receive.sample',
#  '/tmp/repo_fixture/.git/hooks/prepare-commit-msg.sample',
#  '/tmp/repo_fixture/.git/hooks/push-to-checkout.sample',
#  '/tmp/repo_fixture/.git/hooks/sendemail-validate.sample',
#  '/tmp/repo_fixture/.git/hooks/update.sample',
#  '/tmp/repo_fixture/.git/index',
#  '/tmp/repo_fixture/.git/info/exclude',
#  '/tmp/repo_fixture/.git/logs/HEAD',
#  '/tmp/repo_fixture/.git/logs/refs/heads/abranch',
#  '/tmp/repo_fixture/.git/logs/refs/heads/master',
#  '/tmp/repo_fixture/.git/objects/09/c46bfab82020ac6336f787ae3f685781ae1a3b',
#  '/tmp/repo_fixture/.git/objects/1c/37a156abf51aae05b7b970514e19b9689f42ac',
#  '/tmp/repo_fixture/.git/objects/2a/f3a377ee06f86a955bd2a0d9f76cc707cff054',
#  '/tmp/repo_fixture/.git/objects/48/8d13daaaf465b7aad0bb08b8d6bf4f8585fe0a',
#  '/tmp/repo_fixture/.git/objects/51/39238ec364232bcb79141a5fb7f276b4f4001a',
#  '/tmp/repo_fixture/.git/objects/74/c6d7652f98a85286d2d350bd4722211051f889',
#  '/tmp/repo_fixture/.git/objects/94/0920d045f3e0a94b008a5e81a82ea265c19a3a',
#  '/tmp/repo_fixture/.git/objects/9b/faaaf97aab0493e0d369cae65580d3c6d95060',
#  '/tmp/repo_fixture/.git/objects/a9/06852f929f123eedf16e685caafcf5179a572c',
#  '/tmp/repo_fixture/.git/objects/af/f88cec66c6b9b9629ad0a288500b36c7e8479a',
#  '/tmp/repo_fixture/.git/objects/b6/18cd9aad9074b981178ca2f8c41b1f3d95c52f',
#  '/tmp/repo_fixture/.git/objects/cd/ca2c1e94f3d30ed4e7822b2da91c59792899b4',
#  '/tmp/repo_fixture/.git/objects/dd/dfd37cf36ce53b21a12452f9817d9364738c11',
#  '/tmp/repo_fixture/.git/objects/f2/80d164d17fc78ff01c1df10ad27dafe6fcfc2d',
#  '/tmp/repo_fixture/.git/objects/f9/7366e414bbd87b014e1df743f2cb4c7e8e9318',
#  '/tmp/repo_fixture/.git/refs/heads/abranch',
#  '/tmp/repo_fixture/.git/refs/heads/master',
#  '/tmp/repo_fixture/.git/refs/tags/thetag',
#  '/tmp/repo_fixture/file1',
#  '/tmp/repo_fixture/file2',
#  '/tmp/repo_fixture/inner/file3',
#  '/tmp/repo_fixture/inner/file4']

# %% [markdown]
# find() uses walk()
#
# walk() gives folders, each with:
# - list of subfolders
# - list of files
# It recurses subfolders

# %%
for thing in fs_file.walk("/tmp/repo_fixture"):
    print(thing)
# Out:
# ('/tmp/repo_fixture', ['.git', 'inner'], ['file2', 'file1'])
# ('/tmp/repo_fixture/.git', ['branches', 'hooks', 'objects', 'info', 'refs', 'logs'], ['index', 'HEAD', 'config', 'description', 'COMMIT_EDITMSG'])
# ('/tmp/repo_fixture/.git/branches', [], [])
# ('/tmp/repo_fixture/.git/hooks', [], ['fsmonitor-watchman.sample', 'push-to-checkout.sample', 'update.sample', 'pre-applypatch.sample', 'pre-push.sample', 'pre-receive.sample', 'sendemail-validate.sample', 'pre-merge-commit.sample', 'applypatch-msg.sample', 'pre-commit.sample', 'prepare-commit-msg.sample', 'commit-msg.sample', 'post-update.sample', 'pre-rebase.sample'])
# ('/tmp/repo_fixture/.git/objects', ['1c', '51', '48', 'f2', 'pack', '2a', 'a9', '9b', 'cd', 'af', 'f9', '74', '09', '94', 'info', 'b6', 'dd'], [])
# ('/tmp/repo_fixture/.git/objects/1c', [], ['37a156abf51aae05b7b970514e19b9689f42ac'])
# ('/tmp/repo_fixture/.git/objects/51', [], ['39238ec364232bcb79141a5fb7f276b4f4001a'])
# ('/tmp/repo_fixture/.git/objects/48', [], ['8d13daaaf465b7aad0bb08b8d6bf4f8585fe0a'])
# ('/tmp/repo_fixture/.git/objects/f2', [], ['80d164d17fc78ff01c1df10ad27dafe6fcfc2d'])
# ('/tmp/repo_fixture/.git/objects/pack', [], [])
# ('/tmp/repo_fixture/.git/objects/2a', [], ['f3a377ee06f86a955bd2a0d9f76cc707cff054'])
# ('/tmp/repo_fixture/.git/objects/a9', [], ['06852f929f123eedf16e685caafcf5179a572c'])
# ('/tmp/repo_fixture/.git/objects/9b', [], ['faaaf97aab0493e0d369cae65580d3c6d95060'])
# ('/tmp/repo_fixture/.git/objects/cd', [], ['ca2c1e94f3d30ed4e7822b2da91c59792899b4'])
# ('/tmp/repo_fixture/.git/objects/af', [], ['f88cec66c6b9b9629ad0a288500b36c7e8479a'])
# ('/tmp/repo_fixture/.git/objects/f9', [], ['7366e414bbd87b014e1df743f2cb4c7e8e9318'])
# ('/tmp/repo_fixture/.git/objects/74', [], ['c6d7652f98a85286d2d350bd4722211051f889'])
# ('/tmp/repo_fixture/.git/objects/09', [], ['c46bfab82020ac6336f787ae3f685781ae1a3b'])
# ('/tmp/repo_fixture/.git/objects/94', [], ['0920d045f3e0a94b008a5e81a82ea265c19a3a'])
# ('/tmp/repo_fixture/.git/objects/info', [], [])
# ('/tmp/repo_fixture/.git/objects/b6', [], ['18cd9aad9074b981178ca2f8c41b1f3d95c52f'])
# ('/tmp/repo_fixture/.git/objects/dd', [], ['dfd37cf36ce53b21a12452f9817d9364738c11'])
# ('/tmp/repo_fixture/.git/info', [], ['exclude'])
# ('/tmp/repo_fixture/.git/refs', ['tags', 'heads'], [])
# ('/tmp/repo_fixture/.git/refs/tags', [], ['thetag'])
# ('/tmp/repo_fixture/.git/refs/heads', [], ['master', 'abranch'])
# ('/tmp/repo_fixture/.git/logs', ['refs'], ['HEAD'])
# ('/tmp/repo_fixture/.git/logs/refs', ['heads'], [])
# ('/tmp/repo_fixture/.git/logs/refs/heads', [], ['master', 'abranch'])
# ('/tmp/repo_fixture/inner', [], ['file3', 'file4'])

# %% [markdown]
# and walk uses ls()
#
# ls() lists files and directories at the specified level. It does not recurse.

# %%
fs_file.ls("/tmp/repo_fixture")
# Out:
# ['/tmp/repo_fixture/file2',
#  '/tmp/repo_fixture/.git',
#  '/tmp/repo_fixture/inner',
#  '/tmp/repo_fixture/file1']

# %% [markdown]
# ls() can also give object details

# %%
fs_file.ls("/tmp/repo_fixture", detail=True)
# Out:
# [{'name': '/tmp/repo_fixture/file2',
#   'size': 7,
#   'type': 'file',
#   'created': 1703550235.1300154,
#   'islink': False,
#   'mode': 33188,
#   'uid': 1000,
#   'gid': 1000,
#   'mtime': 1703550235.1300154,
#   'ino': 386288,
#   'nlink': 1},
#  {'name': '/tmp/repo_fixture/.git',
#   'size': 4096,
#   'type': 'directory',
#   'created': 1703550235.1600153,
#   'islink': False,
#   'mode': 16877,
#   'uid': 1000,
#   'gid': 1000,
#   'mtime': 1703550235.1600153,
#   'ino': 386236,
#   'nlink': 8},
#  {'name': '/tmp/repo_fixture/inner',
#   'size': 4096,
#   'type': 'directory',
#   'created': 1703550235.1500154,
#   'islink': False,
#   'mode': 16877,
#   'uid': 1000,
#   'gid': 1000,
#   'mtime': 1703550235.1500154,
#   'ino': 386259,
#   'nlink': 2},
#  {'name': '/tmp/repo_fixture/file1',
#   'size': 6,
#   'type': 'file',
#   'created': 1703550235.1300154,
#   'islink': False,
#   'mode': 33188,
#   'uid': 1000,
#   'gid': 1000,
#   'mtime': 1703550235.1300154,
#   'ino': 386264,
#   'nlink': 1}]
